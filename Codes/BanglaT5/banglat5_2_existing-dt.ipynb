# %%
import pandas as pd
from datasets import Dataset

# %%
# with open("/kaggle/input/bengali-news-summarization-dataset/Bengali-News-Summarization-Dataset/article.txt", "r") as f:
#     articles = f.read().splitlines()
    
    
# with open("/kaggle/input/bengali-news-summarization-dataset/Bengali-News-Summarization-Dataset/summary.txt", "r") as f:
#     summaries = f.read().splitlines()

# %%
# df = pd.read_csv('/kaggle/input/cleaneddataa/preprocessed_bangla_news.csv')

# %%
import pandas as pd

# Load the article and summary CSV files without headers
articles_df = pd.read_csv('/kaggle/input/existing-dt/article.csv', header=None)
summaries_df = pd.read_csv('/kaggle/input/existing-dt/summary.csv', header=None)

# Assign column names manually
articles_df.columns = ['article']
summaries_df.columns = ['summary']

# Concatenate them into a single DataFrame for ease of processing
df = pd.concat([articles_df, summaries_df], axis=1)

# Display the first few rows for verification
print(df.head())
# Out:
#                                              article  \
# 0  স্ট্যান্ডার্ড চার্টার্ড ব্যাংকের নতুন প্রধান ন...
# 1  রাজধানী থেকে চামড়া শিল্পগুলো সাভারে স্থানান্তর...
# 2  দেশীয় শিল্প বিকাশে সরকারের সব ধরনের উদ্যোগ অব্...
# 3  একীভূত হতে চলেছে অনলাইনে শ্রেণিবদ্ধ বিজ্ঞাপন স...
# 4  যাত্রীবাহী একটি বাসে আগুন দেওয়ার আধা ঘণ্টার মধ...
#
#                                              summary
# 0          স্ট্যান্ডার্ড চার্টার্ডের নতুন সিইও আবরার
# 1  মার্চের মধ্যে সাভারে চামড়া শিল্পের সিইটিপি: মন...
# 2                       ওয়ালটন কারখানায় শিল্পমন্ত্রী
# 3                    একীভূত হচ্ছে এখানেই ডটকমওএলএক্স
# 4              বাসে আগুন: নড়াইলের পৌর মেয়র গ্রেপ্তার

# %%
# df = pd.DataFrame(list(zip(articles,summaries)),columns=["article","summary"])

# %%
df
# Out:
#                                                  article  \
# 0      স্ট্যান্ডার্ড চার্টার্ড ব্যাংকের নতুন প্রধান ন...
# 1      রাজধানী থেকে চামড়া শিল্পগুলো সাভারে স্থানান্তর...
# 2      দেশীয় শিল্প বিকাশে সরকারের সব ধরনের উদ্যোগ অব্...
# 3      একীভূত হতে চলেছে অনলাইনে শ্রেণিবদ্ধ বিজ্ঞাপন স...
# 4      যাত্রীবাহী একটি বাসে আগুন দেওয়ার আধা ঘণ্টার মধ...
# ...                                                  ...
# 19091  মাঝারি থেকে দূরপাল্লার ক্ষেপণাস্ত্রের সফল পরীক...
# 19092  বিশ্বকবি রবীন্দ্রনাথ ঠাকুরের ১৫৬তম ও জাতীয় কবি...
# 19093  এশিয়ান কন্টিনেন্টাল দাবা চ্যাম্পিয়নশিপের চতুর্...
# 19094  শাখার পূর্ণাঙ্গ কমিটি করতে না পারার জন্য বড় ভা...
# 19095  বাংলাদেশ অ্যাসোসিয়েশন অফ ব্যাংকস বিএবি প্রধানম...
#
#                                                  summary
# 0              স্ট্যান্ডার্ড চার্টার্ডের নতুন সিইও আবরার
# 1      মার্চের মধ্যে সাভারে চামড়া শিল্পের সিইটিপি: মন...
# 2                           ওয়ালটন কারখানায় শিল্পমন্ত্রী
# 3                        একীভূত হচ্ছে এখানেই ডটকমওএলএক্স
# 4                  বাসে আগুন: নড়াইলের পৌর মেয়র গ্রেপ্তার
# ...                                                  ...
# 19091  যেকোনও সময় ফের ক্ষেপণাস্ত্র পরীক্ষার হুমকি উত্...
# 19092            আবুধাবিতে রবীন্দ্রনজরুল জন্মজয়ন্তী পালন
# 19093                             চীনে রাজীব ও লিজার ড্র
# 19094              বড় ভাইদের দাবি মেটাতে হিমশিম ছাত্রলীগ
# 19095  প্রধানমন্ত্রীর হাতে বিএবির ১৩৬ কোটি টাকা অনুদা...
#
# [19096 rows x 2 columns]

# %%
df.dropna()
# Out:
#                                                  article  \
# 0      স্ট্যান্ডার্ড চার্টার্ড ব্যাংকের নতুন প্রধান ন...
# 1      রাজধানী থেকে চামড়া শিল্পগুলো সাভারে স্থানান্তর...
# 2      দেশীয় শিল্প বিকাশে সরকারের সব ধরনের উদ্যোগ অব্...
# 3      একীভূত হতে চলেছে অনলাইনে শ্রেণিবদ্ধ বিজ্ঞাপন স...
# 4      যাত্রীবাহী একটি বাসে আগুন দেওয়ার আধা ঘণ্টার মধ...
# ...                                                  ...
# 19091  মাঝারি থেকে দূরপাল্লার ক্ষেপণাস্ত্রের সফল পরীক...
# 19092  বিশ্বকবি রবীন্দ্রনাথ ঠাকুরের ১৫৬তম ও জাতীয় কবি...
# 19093  এশিয়ান কন্টিনেন্টাল দাবা চ্যাম্পিয়নশিপের চতুর্...
# 19094  শাখার পূর্ণাঙ্গ কমিটি করতে না পারার জন্য বড় ভা...
# 19095  বাংলাদেশ অ্যাসোসিয়েশন অফ ব্যাংকস বিএবি প্রধানম...
#
#                                                  summary
# 0              স্ট্যান্ডার্ড চার্টার্ডের নতুন সিইও আবরার
# 1      মার্চের মধ্যে সাভারে চামড়া শিল্পের সিইটিপি: মন...
# 2                           ওয়ালটন কারখানায় শিল্পমন্ত্রী
# 3                        একীভূত হচ্ছে এখানেই ডটকমওএলএক্স
# 4                  বাসে আগুন: নড়াইলের পৌর মেয়র গ্রেপ্তার
# ...                                                  ...
# 19091  যেকোনও সময় ফের ক্ষেপণাস্ত্র পরীক্ষার হুমকি উত্...
# 19092            আবুধাবিতে রবীন্দ্রনজরুল জন্মজয়ন্তী পালন
# 19093                             চীনে রাজীব ও লিজার ড্র
# 19094              বড় ভাইদের দাবি মেটাতে হিমশিম ছাত্রলীগ
# 19095  প্রধানমন্ত্রীর হাতে বিএবির ১৩৬ কোটি টাকা অনুদা...
#
# [19096 rows x 2 columns]

# %%
df
# Out:
#                                                  article  \
# 0      স্ট্যান্ডার্ড চার্টার্ড ব্যাংকের নতুন প্রধান ন...
# 1      রাজধানী থেকে চামড়া শিল্পগুলো সাভারে স্থানান্তর...
# 2      দেশীয় শিল্প বিকাশে সরকারের সব ধরনের উদ্যোগ অব্...
# 3      একীভূত হতে চলেছে অনলাইনে শ্রেণিবদ্ধ বিজ্ঞাপন স...
# 4      যাত্রীবাহী একটি বাসে আগুন দেওয়ার আধা ঘণ্টার মধ...
# ...                                                  ...
# 19091  মাঝারি থেকে দূরপাল্লার ক্ষেপণাস্ত্রের সফল পরীক...
# 19092  বিশ্বকবি রবীন্দ্রনাথ ঠাকুরের ১৫৬তম ও জাতীয় কবি...
# 19093  এশিয়ান কন্টিনেন্টাল দাবা চ্যাম্পিয়নশিপের চতুর্...
# 19094  শাখার পূর্ণাঙ্গ কমিটি করতে না পারার জন্য বড় ভা...
# 19095  বাংলাদেশ অ্যাসোসিয়েশন অফ ব্যাংকস বিএবি প্রধানম...
#
#                                                  summary
# 0              স্ট্যান্ডার্ড চার্টার্ডের নতুন সিইও আবরার
# 1      মার্চের মধ্যে সাভারে চামড়া শিল্পের সিইটিপি: মন...
# 2                           ওয়ালটন কারখানায় শিল্পমন্ত্রী
# 3                        একীভূত হচ্ছে এখানেই ডটকমওএলএক্স
# 4                  বাসে আগুন: নড়াইলের পৌর মেয়র গ্রেপ্তার
# ...                                                  ...
# 19091  যেকোনও সময় ফের ক্ষেপণাস্ত্র পরীক্ষার হুমকি উত্...
# 19092            আবুধাবিতে রবীন্দ্রনজরুল জন্মজয়ন্তী পালন
# 19093                             চীনে রাজীব ও লিজার ড্র
# 19094              বড় ভাইদের দাবি মেটাতে হিমশিম ছাত্রলীগ
# 19095  প্রধানমন্ত্রীর হাতে বিএবির ১৩৬ কোটি টাকা অনুদা...
#
# [19096 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, test_size=0.30, shuffle=True)
df_val, df_test = train_test_split(df_test, test_size=0.65,shuffle=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df_train
# Out:
#                                                  article  \
# 523    বন্দরনগরী চট্টগ্রামে দায়িত্ব পালনরত অবস্থায় এক...
# 744    নরসিংদী সদর উপজেলায় মেঘনা নদীতে নৌকা ডুবে শিশু...
# 16124  ঘুষ না দেওয়ায় চট্টগ্রাম সিটি করপোরেশনে বরাদ্দ ...
# 16134  এক মাস ধরে পিছু পিছু ঘোরার পর ভারতীয় বুনো হাতি...
# 17209  অলিম্পিক শহর ব্রাজিলের রিও ডি জেনেইরোতে ডাকাতি...
# ...                                                  ...
# 7297   লাঙ্গলবন্দে অষ্টমী স্নানে পুণ্যার্থীর মৃত্যুর ...
# 3609   ভিয়ারিয়ালের বিপক্ষে রোমাঞ্চকর জয়ের আনন্দে উচ্ছ...
# 15531  পর পর দুটি ব্লকব্লাস্টার ছবি বাজরাঙ্গি ভাইজান ...
# 9188   হঠাৎ করেই বিশ্বকাপে বাংলাদেশ দলে ডাক পেয়ে চমকে...
# 9897   মাদক নিয়ন্ত্রণ অধিদপ্তরের অনুমোদন ছাড়া কার্যক্...
#
#                                                  summary
# 523    চট্টগ্রামে দায়িত্ব পালনকালে ট্রাফিক পুলিশের মৃ...
# 744              মেঘনায় নৌকা ডুবে মামেয়েসহ ৩ জনের মৃত্যু
# 16124               নাছিরের কথার ব্যাখ্যা চায় মন্ত্রণালয়
# 16134                               অবশেষে হাতিটির নাগাল
# 17209  রিওতে ডাকাতির গল্প ফেঁদে জরিমানা গুণছেন মার্কি...
# ...                                                  ...
# 7297        লাঙ্গলবন্দে মৃত্যু: দুর্নীতির অভিযোগ বিএনপির
# 3609                          মেসি, নেইমারে মুগ্ধ এনরিকে
# 15531                      সাইফকে টপকে রেসথ্রি তে সালমান
# 9188   বিশ্বকাপে সামর্থ্যের সেরাটা দেওয়ার প্রতিশ্রুতি...
# 9897   চট্টগ্রামে অবৈধ মাদকাসক্তি নিরাময় কেন্দ্র সিলগালা
#
# [13367 rows x 2 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def visualize_text_length(data, title):
    # Drop rows with NaN values in clean_article or clean_summary columns
    data = data.dropna(subset=['article', 'summary'])

    # Apply len() to the clean_article and clean_summary columns
    data['News_article_text_length'] = data['article'].apply(len)
    data['News_summary_text_length'] = data['summary'].apply(len)

    # Plotting
    plt.figure(figsize=(8, 4))
    sns.histplot(data['News_article_text_length'], bins=30, color='blue', label='Article Length')
    sns.histplot(data['News_summary_text_length'], bins=30, color='red', label='Summary Length')
    plt.title(title)
    plt.xlabel('Text Length')
    plt.ylabel('Frequency')
    plt.legend()
    plt.show()

# %% [markdown]
# # **Visualize text length distribution for each dataset**

# %%
visualize_text_length(df_train, 'Training Dataset')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
visualize_text_length(df_test , 'Test Dataset')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
visualize_text_length(df_val , 'Validation Dataset')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# from wordcloud import WordCloud

# def create_wordcloud(data, column, title):
#     # Specify a Bangla-supported font, such as "Siyam Rupali"
#     font_path = "/kaggle/input/fonts-paths/Siyam Rupali Regular.ttf"


#     #This setting disables the detection of collocations (multi-word phrases) to focus on individual words.
#     wordcloud = WordCloud(width=800, height=400, background_color='black', font_path=font_path,
#                           colormap='rainbow', collocations=False).generate(' '.join(data[column]))

#     plt.figure(figsize=(8, 4))
#     plt.imshow(wordcloud, interpolation='bilinear')
#     plt.title(f'Word Cloud for {column} in {title}', fontsize=16, color='black')
#     plt.axis('off')
#     plt.show()

# %%
# create_wordcloud(df_train, 'article', 'Training Set')

# %%
# create_wordcloud(df_train, 'summary', 'Training Set')

# %%
# !pip install git+https://github.com/csebuetnlp/normalizer
# Out:
# Collecting git+https://github.com/csebuetnlp/normalizer
#   Cloning https://github.com/csebuetnlp/normalizer to /tmp/pip-req-build-sd6lb4tu
#   Running command git clone --filter=blob:none --quiet https://github.com/csebuetnlp/normalizer /tmp/pip-req-build-sd6lb4tu
#   Resolved https://github.com/csebuetnlp/normalizer to commit d405944dde5ceeacb7c2fd3245ae2a9dea5f35c9
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: regex in /opt/conda/lib/python3.10/site-packages (from normalizer==0.0.1) (2023.8.8)
# Collecting emoji==1.4.2 (from normalizer==0.0.1)
#   Downloading emoji-1.4.2.tar.gz (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.0/185.0 kB 8.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting ftfy==6.0.3 (from normalizer==0.0.1)
#   Downloading ftfy-6.0.3.tar.gz (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 7.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from ftfy==6.0.3->normalizer==0.0.1) (0.2.6)
# Building wheels for collected packages: normalizer, emoji, ftfy
#   Building wheel for normalizer (setup.py) ... done
#   Created wheel for normalizer: filename=normalizer-0.0.1-py3-none-any.whl size=6857 sha256=06a82c597bba95e493a843f905cd9a7db70c0ac63b75d2a7999baf34c77721c0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-62f3fiud/wheels/2e/79/9c/cd96d490298305d51d2da11484bb2c25fd1f759a6906708282
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.4.2-py3-none-any.whl size=186459 sha256=826e9e9300d5c2af4a17d18997681d521982215b2ed9567f64ec8c4befe02437
#   Stored in directory: /root/.cache/pip/wheels/10/f0/fd/4813b1177405693e8da9cdea839f0fb64fde161380e058c827
#   Building wheel for ftfy (setup.py) ... done
#   Created wheel for ftfy: filename=ftfy-6.0.3-py3-none-any.whl size=41930 sha256=d28e0d8b791d5194e657eab65021dfaa3345aaa76fd626a67f84efc8dae9ce63
#   Stored in directory: /root/.cache/pip/wheels/92/8e/16/c1e4d4d65685d71085e4e27b44d6ed880b0559474c9ee4ff66
# Successfully built normalizer emoji ftfy
# Installing collected packages: emoji, ftfy, normalizer
#   Attempting uninstall: emoji
#     Found existing installation: emoji 2.9.0
#     Uninstalling emoji-2.9.0:
#       Successfully uninstalled emoji-2.9.0
# Successfully installed emoji-1.4.2 ftfy-6.0.3 normalizer-0.0.1

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
from normalizer import normalize # pip install git+https://github.com/csebuetnlp/normalizer

# %%
import torch
from normalizer import normalize
from transformers import MT5ForConditionalGeneration, AutoTokenizer ,DataCollatorForSeq2Seq, Trainer, TrainingArguments
import os


model_name = "csebuetnlp/banglat5" 
model = MT5ForConditionalGeneration.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# You are using a model of type t5 to instantiate a model of type mt5. This is not supported for all configurations of models and can yield errors.

# %%
model_name
# Out:
# 'csebuetnlp/banglat5'

# %%
from torch.utils.data import Dataset, DataLoader

class Seq2SeqDataset(Dataset):
    def __init__(self, data, tokenizer, max_length=128):
        # Drop rows with NaN values in clean_article or clean_summary columns
        data = data.dropna(subset=['article', 'summary'])

        # Normalize and tokenize input text and labels
        self.input_text = data['article'].apply(normalize).tolist()
        self.labels = data['summary'].apply(normalize).tolist()
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.input_text)

    def __getitem__(self, idx):
        # Tokenize the input and labels
        inputs = self.tokenizer(self.input_text[idx], 
                                max_length=self.max_length, 
                                padding='max_length', 
                                truncation=True, 
                                return_tensors="pt")

        labels = self.tokenizer(self.labels[idx], 
                                max_length=self.max_length, 
                                padding='max_length', 
                                truncation=True, 
                                return_tensors="pt")

        # Return input and labels for the sample
        return {
            'input_ids': inputs['input_ids'].squeeze(), 
            'attention_mask': inputs['attention_mask'].squeeze(), 
            'labels': labels['input_ids'].squeeze()
        }

# %%
import torch
from transformers import DataCollatorForSeq2Seq
from torch.nn.utils.rnn import pad_sequence

class MyDataCollatorForSeq2Seq(DataCollatorForSeq2Seq):
    def __call__(self, features):
        batch = {}

        # Handle input_ids and attention_mask
        batch["input_ids"] = torch.stack([feature["input_ids"] for feature in features])
        batch["attention_mask"] = torch.stack([feature["attention_mask"] for feature in features])

        # Check if the labels are PyTorch tensors
        if isinstance(features[0]["labels"], torch.Tensor):
            # Ensure padding for labels is handled correctly
            batch["labels"] = torch.stack([feature["labels"] for feature in features])
        else:
            # Convert list of lists (if not tensor) to tensor and pad
            batch["labels"] = torch.tensor([feature["labels"] for feature in features], dtype=torch.long)

        # Make sure labels are padded if necessary (for variable-length sequences)
        if self.label_pad_token_id is not None:
            batch["labels"] = pad_sequence([feature["labels"] for feature in features], 
                                           batch_first=True, 
                                           padding_value=self.label_pad_token_id)

        return batch

# %%
# Create train, test, and validation datasets
train_dataset = Seq2SeqDataset(df_train, tokenizer)
test_dataset = Seq2SeqDataset(df_test, tokenizer)
validation_dataset = Seq2SeqDataset(df_val, tokenizer)

# Create DataLoader for each dataset
train_dataloader = DataLoader(train_dataset, 
                              batch_size=16, 
                              shuffle=True, 
                              collate_fn=MyDataCollatorForSeq2Seq(tokenizer))

test_dataloader = DataLoader(test_dataset, 
                             batch_size=16, 
                             collate_fn=MyDataCollatorForSeq2Seq(tokenizer))

validation_dataloader = DataLoader(validation_dataset, 
                                   batch_size=16, 
                                   collate_fn=MyDataCollatorForSeq2Seq(tokenizer))

# %%
# Move the model to the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cuda')

# %%
# Create a custom optimizer using torch.optim.AdamW
custom_optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=1e-3,
    eps=1e-8,
    weight_decay=0.01,
)

# %%
# Define the TrainingArguments for fine-tuning
training_args = TrainingArguments(
    output_dir='/kaggle/working/',
    num_train_epochs=6,
    per_device_train_batch_size=10,
    gradient_accumulation_steps=8,
    evaluation_strategy="epoch",
    save_total_limit=1,
    save_steps=5000,
    learning_rate=1e-3,
    do_train=True,
    do_eval=True,
    remove_unused_columns=False,
    push_to_hub=False,
    report_to="none",
    load_best_model_at_end=False,
    lr_scheduler_type="cosine_with_restarts",
    warmup_steps=100,
    weight_decay=0.01,
    logging_dir='/kaggle/working/',
    logging_steps=200,
    
)

# %%
data_collator = MyDataCollatorForSeq2Seq(
    tokenizer=tokenizer,
    model=model,
    padding=True,  # Padding to the model's max length
    max_length=128,  # Use the same max length as during tokenization
    label_pad_token_id=tokenizer.pad_token_id,
)

# %%
# Create Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=train_dataset,
    eval_dataset=validation_dataset,
    optimizers=(custom_optimizer, None),
)

# %%
# Fine-tune the model
trainer.train()
# Out:
#     <div>
#
#       <progress value='1002' max='1002' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1002/1002 50:29, Epoch 5/6]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>No log</td>
#       <td>0.476494</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>16.118000</td>
#       <td>0.194266</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.339600</td>
#       <td>0.148949</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.176800</td>
#       <td>0.141237</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.151300</td>
#       <td>0.139435</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.143900</td>
#       <td>0.139424</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1002, training_loss=3.37945147507086, metrics={'train_runtime': 3033.2589, 'train_samples_per_second': 26.441, 'train_steps_per_second': 0.33, 'total_flos': 1.371996950298624e+16, 'train_loss': 3.37945147507086, 'epoch': 6.0})

# %%
from transformers import AutoModelForSeq2SeqLM

# Save the model
model.save_pretrained("/kaggle/working/banglat5_model.pt")

# Save the tokenizer
tokenizer.save_pretrained("/kaggle/working/banglat5_tokenizer.json")
# Out:
# ('/kaggle/working/banglat5_tokenizer.json/tokenizer_config.json',
#  '/kaggle/working/banglat5_tokenizer.json/special_tokens_map.json',
#  '/kaggle/working/banglat5_tokenizer.json/spiece.model',
#  '/kaggle/working/banglat5_tokenizer.json/added_tokens.json',
#  '/kaggle/working/banglat5_tokenizer.json/tokenizer.json')

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

# Load the saved model
model = AutoModelForSeq2SeqLM.from_pretrained("/kaggle/working/banglat5_model.pt")

# Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained("/kaggle/working/banglat5_tokenizer.json")

# %%
# !pip install datasets
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (2.1.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from datasets) (1.24.3)
# Requirement already satisfied: pyarrow>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (11.0.0)
# Requirement already satisfied: dill in /opt/conda/lib/python3.10/site-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /opt/conda/lib/python3.10/site-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (2023.12.2)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets) (3.8.5)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.19.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from datasets) (21.3)
# Requirement already satisfied: responses<0.19 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.18.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.12.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (4.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
# !pip install python-Levenshtein
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: python-Levenshtein in /opt/conda/lib/python3.10/site-packages (0.23.0)
# Requirement already satisfied: Levenshtein==0.23.0 in /opt/conda/lib/python3.10/site-packages (from python-Levenshtein) (0.23.0)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from Levenshtein==0.23.0->python-Levenshtein) (3.5.2)

# %%
# !pip install jiwer
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting jiwer
#   Obtaining dependency information for jiwer from https://files.pythonhosted.org/packages/00/b9/113eba899451e6dc2acd3a3637ce9ef327ea6dea2e7a93dcd3523197f395/jiwer-3.0.4-py3-none-any.whl.metadata
#   Downloading jiwer-3.0.4-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /opt/conda/lib/python3.10/site-packages (from jiwer) (8.1.7)
# Requirement already satisfied: rapidfuzz<4,>=3 in /opt/conda/lib/python3.10/site-packages (from jiwer) (3.5.2)
# Downloading jiwer-3.0.4-py3-none-any.whl (21 kB)
# Installing collected packages: jiwer
# Successfully installed jiwer-3.0.4

# %%
# Move the model to the device (CPU or GPU)
model.to(device)
# Out:
# MT5ForConditionalGeneration(
#   (shared): Embedding(32128, 768)
#   (encoder): MT5Stack(
#     (embed_tokens): Embedding(32128, 768)
#     (block): ModuleList(
#       (0): MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): MT5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): MT5Stack(
#     (embed_tokens): Embedding(32128, 768)
#     (block): ModuleList(
#       (0): MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerCrossAttention(
#             (EncDecAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerCrossAttention(
#             (EncDecAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): MT5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=768, out_features=32128, bias=False)
# )

# %%
# !pip install rouge-score
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.10/site-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (from rouge-score) (3.2.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from rouge-score) (1.24.3)
# Requirement already satisfied: six>=1.14.0 in /opt/conda/lib/python3.10/site-packages (from rouge-score) (1.16.0)
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24932 sha256=13fa9ead5e6e4dd8d8388869e96a330a556e13eab491550a2a53952de7d0a73c
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge-score
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.1.2

# %%
# !pip install evaluate
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting evaluate
#   Obtaining dependency information for evaluate from https://files.pythonhosted.org/packages/a2/e7/cbca9e2d2590eb9b5aa8f7ebabe1beb1498f9462d2ecede5c9fd9735faaf/evaluate-0.4.3-py3-none-any.whl.metadata
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: datasets>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from evaluate) (2.1.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from evaluate) (1.24.3)
# Requirement already satisfied: dill in /opt/conda/lib/python3.10/site-packages (from evaluate) (0.3.7)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from evaluate) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.10/site-packages (from evaluate) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /opt/conda/lib/python3.10/site-packages (from evaluate) (4.66.1)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from evaluate) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from evaluate) (0.70.15)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /opt/conda/lib/python3.10/site-packages (from evaluate) (2023.12.2)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from evaluate) (0.19.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from evaluate) (21.3)
# Requirement already satisfied: pyarrow>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate) (11.0.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate) (3.8.5)
# Requirement already satisfied: responses<0.19 in /opt/conda/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate) (0.18.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.7.0->evaluate) (3.12.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.7.0->evaluate) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.7.0->evaluate) (4.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->evaluate) (3.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->evaluate) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->evaluate) (2023.3)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 5.1 MB/s eta 0:00:00
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.3

# %%
import torch
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from rouge_score import rouge_scorer
from nltk.tokenize import word_tokenize

# Define the move_to_device function
def move_to_device(batch, device):
    if isinstance(batch, torch.Tensor):
        return batch.to(device)
    elif isinstance(batch, list):
        return [move_to_device(item, device) for item in batch]
    elif isinstance(batch, dict):
        return {key: move_to_device(value, device) for key, value in batch.items()}
    else:
        return batch  # If it's not a tensor, list, or dict, leave it as is

# Smoothing function for BLEU
smoothing_function = SmoothingFunction().method4

# Initialize lists to store generated summaries and references
generated_summaries = []
references = []

# Tokenizer function
def tokenize(text):
    return word_tokenize(text)

# Generate summaries for the test dataset
for batch in test_dataloader:
    # Move the batch to CUDA
    batch = move_to_device(batch, 'cuda')

    input_text = batch['input_ids']  # Access the input_text using the correct key
    labels = batch['labels']  # Access the labels using the correct key

    # Generate summaries
    with torch.no_grad():  # Disable gradient calculation to save memory
        max_length = int(input_text.shape[1] * 0.3)  # Set max_length dynamically
        summary_ids = model.generate(
            input_text,
            max_length=max_length,
            num_beams=4,
            length_penalty=1.0,
            early_stopping=True
        )

    # Move the summary_ids to CPU to decode
    summary_ids = summary_ids.to('cpu')

    # Decode generated summaries and labels
    generated_summary = tokenizer.batch_decode(summary_ids, skip_special_tokens=True)
    reference_summary = tokenizer.batch_decode(labels, skip_special_tokens=True)

    # Extend lists with generated summaries and references
    generated_summaries.extend(generated_summary)
    references.extend(reference_summary)

# Filter out empty predictions and references
filtered_generated_summaries = []
filtered_references = []

for pred, ref in zip(generated_summaries, references):
    if pred.strip() and ref.strip():  # Check if both are non-empty
        filtered_generated_summaries.append(pred)
        filtered_references.append(ref)

# Debug: Check the lengths of the filtered summaries
print(f"Filtered Generated Summaries Count: {len(filtered_generated_summaries)}")
print(f"Filtered References Count: {len(filtered_references)}")

# Calculate BLEU score only for non-empty summaries
bleu_scores = []
for pred, ref in zip(filtered_generated_summaries, filtered_references):
    pred_tokens = tokenize(pred)  # Use consistent tokenization
    ref_tokens = tokenize(ref)
    print(f"Pred Length: {len(pred_tokens)}, Ref Length: {len(ref_tokens)}")  # Debug lengths
    if pred_tokens and ref_tokens:  # Ensure both are non-empty after tokenization
        score = sentence_bleu([ref_tokens], pred_tokens, smoothing_function=smoothing_function)
        bleu_scores.append(score)

avg_bleu_score = sum(bleu_scores) / len(bleu_scores) if bleu_scores else 0  # Calculate average if scores exist

# Calculate ROUGE score without stemming
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=False)
rouge_scores = {key: [] for key in ['rouge1', 'rouge2', 'rougeL']}
for pred, ref in zip(filtered_generated_summaries, filtered_references):
    scores = scorer.score(ref, pred)  # Ensure order is reference first
    for key in rouge_scores:
        rouge_scores[key].append(scores[key].fmeasure)

avg_rouge_scores = {key: sum(val) / len(val) for key, val in rouge_scores.items()}

# Print the results
print(f"BLEU Score: {avg_bleu_score}")
print(f"ROUGE Scores: {avg_rouge_scores}")
# Out:
# Filtered Generated Summaries Count: 3724
# Filtered References Count: 3724
# Pred Length: 7, Ref Length: 7
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 7
# Pred Length: 4, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 7, Ref Length: 6
# Pred Length: 4, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 6, Ref Length: 3
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 4
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 8
# Pred Length: 8, Ref Length: 6
# Pred Length: 2, Ref Length: 4
# Pred Length: 7, Ref Length: 6
# Pred Length: 4, Ref Length: 6
# Pred Length: 4, Ref Length: 4
# Pred Length: 4, Ref Length: 7
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 7
# Pred Length: 8, Ref Length: 8
# Pred Length: 5, Ref Length: 4
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 3
# Pred Length: 5, Ref Length: 7
# Pred Length: 4, Ref Length: 5
# Pred Length: 3, Ref Length: 3
# Pred Length: 5, Ref Length: 3
# Pred Length: 7, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 7, Ref Length: 6
# Pred Length: 8, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 4
# Pred Length: 9, Ref Length: 9
# Pred Length: 5, Ref Length: 8
# Pred Length: 5, Ref Length: 4
# Pred Length: 6, Ref Length: 6
# Pred Length: 7, Ref Length: 4
# Pred Length: 7, Ref Length: 5
# Pred Length: 4, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 4
# Pred Length: 6, Ref Length: 5
# Pred Length: 8, Ref Length: 9
# Pred Length: 2, Ref Length: 4
# Pred Length: 6, Ref Length: 6
# Pred Length: 3, Ref Length: 3
# Pred Length: 9, Ref Length: 6
# Pred Length: 6, Ref Length: 7
# Pred Length: 5, Ref Length: 7
# Pred Length: 6, Ref Length: 5
# Pred Length: 4, Ref Length: 7
# Pred Length: 4, Ref Length: 3
# Pred Length: 8, Ref Length: 7
# Pred Length: 6, Ref Length: 6
# Pred Length: 6, Ref Length: 4
# Pred Length: 9, Ref Length: 7
# Pred Length: 7, Ref Length: 9
# Pred Length: 5, Ref Length: 7
# Pred Length: 5, Ref Length: 4
# Pred Length: 10, Ref Length: 9
# Pred Length: 9, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 7
# Pred Length: 6, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 7
# Pred Length: 3, Ref Length: 4
# Pred Length: 4, Ref Length: 4
# Pred Length: 4, Ref Length: 4
# Pred Length: 3, Ref Length: 5
# Pred Length: 7, Ref Length: 5
# Pred Length: 7, Ref Length: 5
# Pred Length: 4, Ref Length: 5
# Pred Length: 4, Ref Length: 5
# Pred Length: 7, Ref Length: 6
# Pred Length: 7, Ref Length: 7
# Pred Length: 6, Ref Length: 6
# Pred Length: 6, Ref Length: 7
# Pred Length: 8, Ref Length: 8
# Pred Length: 9, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 3, Ref Length: 3
# Pred Length: 7, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 9, Ref Length: 7
# Pred Length: 5, Ref Length: 9
# Pred Length: 4, Ref Length: 6
# Pred Length: 9, Ref Length: 8
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 9
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 7
# Pred Length: 6, Ref Length: 5
# Pred Length: 3, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 7, Ref Length: 6
# Pred Length: 5, Ref Length: 7
# Pred Length: 5, Ref Length: 7
# Pred Length: 7, Ref Length: 8
# Pred Length: 6, Ref Length: 7
# Pred Length: 4, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 8, Ref Length: 9
# Pred Length: 4, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 7
# Pred Length: 5, Ref Length: 8
# Pred Length: 4, Ref Length: 7
# Pred Length: 5, Ref Length: 6
# Pred Length: 7, Ref Length: 8
# Pred Length: 5, Ref Length: 5
# Pred Length: 7, Ref Length: 6
# Pred Length: 5, Ref Length: 6
# Pred Length: 5, Ref Length: 4
# Pred Length: 4, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 4
# Pred Length: 8, Ref Length: 6
# Pred Length: 4, Ref Length: 5
# Pred Length: 8, Ref Length: 9
# Pred Length: 5, Ref Length: 4
# Pred Length: 5, Ref Length: 7
# Pred Length: 6, Ref Length: 7
# Pred Length: 8, Ref Length: 9
# Pred Length: 9, Ref Length: 6
# Pred Length: 6, Ref Length: 4
# Pred Length: 7, Ref Length: 7
# Pred Length: 9, Ref Length: 6
# Pred Length: 9, Ref Length: 6
# Pred Length: 9, Ref Length: 6
# Pred Length: 5, Ref Length: 4
# Pred Length: 5, Ref Length: 6
# Pred Length: 5, Ref Length: 4
# Pred Length: 6, Ref Length: 7
# Pred Length: 5, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 7, Ref Length: 7
# Pred Length: 5, Ref Length: 4
# Pred Length: 3, Ref Length: 3
# Pred Length: 6, Ref Length: 5
# Pred Length: 4, Ref Length: 8
# Pred Length: 5, Ref Length: 4
# Pred Length: 5, Ref Length: 6
# Pred Length: 7, Ref Length: 6
# Pred Length: 6, Ref Length: 9
# Pred Length: 4, Ref Length: 5
# Pred Length: 6, Ref Length: 8
# Pred Length: 3, Ref Length: 3
# Pred Length: 6, Ref Length: 7
# Pred Length: 5, Ref Length: 6
# Pred Length: 4, Ref Length: 7
# Pred Length: 8, Ref Length: 8
# Pred Length: 5, Ref Length: 7
# Pred Length: 4, Ref Length: 5
# Pred Length: 8, Ref Length: 9
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 7
# Pred Length: 7, Ref Length: 6
# Pred Length: 7, Ref Length: 8
# Pred Length: 3, Ref Length: 6
# Pred Length: 5, Ref Length: 6
# Pred Length: 6, Ref Length: 7
# Pred Length: 3, Ref Length: 7
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 8, Ref Length: 8
# Pred Length: 5, Ref Length: 4
# Pred Length: 5, Ref Length: 7
# Pred Length: 8, Ref Length: 5
# Pred Length: 4, Ref Length: 5
# Pred Length: 7, Ref Length: 6
# Pred Length: 5, Ref Length: 6
# Pred Length: 10, Ref Length: 4
# Pred Length: 9, Ref Length: 7
# Pred Length: 7, Ref Length: 8
# Pred Length: 4, Ref Length: 7
# Pred Length: 4, Ref Length: 6
# Pred Length: 8, Ref Length: 6
# Pred Length: 6, Ref Length: 4
# Pred Length: 9, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 7, Ref Length: 6
# Pred Length: 4, Ref Length: 4
# Pred Length: 7, Ref Length: 9
# Pred Length: 6, Ref Length: 7
# Pred Length: 5, Ref Length: 6
# Pred Length: 7, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 7
# Pred Length: 6, Ref Length: 6
# Pred Length: 7, Ref Length: 8
# Pred Length: 3, Ref Length: 11
# Pred Length: 2, Ref Length: 4
# Pred Length: 5, Ref Length: 8
# Pred Length: 7, Ref Length: 6
# Pred Length: 3, Ref Length: 5
# Pred Length: 5, Ref Length: 4
# Pred Length: 5, Ref Length: 6
# Pred Length: 7, Ref Length: 6
# Pred Length: 4, Ref Length: 4
# Pred Length: 6, Ref Length: 7
# Pred Length: 7, Ref Length: 4
# Pred Length: 3, Ref Length: 4
# Pred Length: 4, Ref Length: 4
# Pred Length: 3, Ref Length: 6
# Pred Length: 5, Ref Length: 6
# Pred Length: 7, Ref Length: 6
# Pred Length: 8, Ref Length: 6
# Pred Length: 8, Ref Length: 6
# Pred Length: 4, Ref Length: 6
# Pred Length: 5, Ref Length: 8
# Pred Length: 4, Ref Length: 4
# Pred Length: 6, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 9, Ref Length: 10
# Pred Length: 6, Ref Length: 3
# Pred Length: 5, Ref Length: 7
# Pred Length: 6, Ref Length: 6
# Pred Length: 4, Ref Length: 7
# Pred Length: 4, Ref Length: 5
# Pred Length: 8, Ref Length: 3
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 6
# Pred Length: 5, Ref Length: 8
# Pred Length: 6, Ref Length: 7
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 4
# Pred Length: 9, Ref Length: 5
# Pred Length: 7, Ref Length: 7
# Pred Length: 7, Ref Length: 7
# Pred Length: 9, Ref Length: 8
# Pred Length: 4, Ref Length: 3
# Pred Length: 8, Ref Length: 5
# Pred Length: 6, Ref Length: 9
# Pred Length: 10, Ref Length: 6
# Pred Length: 6, Ref Length: 8
# Pred Length: 9, Ref Length: 7
# Pred Length: 6, Ref Length: 7
# Pred Length: 4, Ref Length: 7
# Pred Length: 7, Ref Length: 7
# Pred Length: 7, Ref Length: 6
# Pred Length: 7, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 6
# Pred Length: 5, Ref Length: 3
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 6
# Pred Length: 5, Ref Length: 7
# Pred Length: 7, Ref Length: 3
# Pred Length: 7, Ref Length: 8
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 5
# Pred Length: 6, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 5, Ref Length: 8
# Pred Length: 5, Ref Length: 6
# Pred Length: 4, Ref Length: 6
# Pred Length: 3, Ref Length: 4
# Pred Length: 6, Ref Length: 4
# Pred Length: 5, Ref Length: 6
# Pred Length: 8, Ref Length: 9
# Pred Length: 5, Ref Length: 7
# Pred Length: 7, Ref Length: 8
# Pred Length: 5, Ref Length: 5
# Pred Length: 8, Ref Length: 9
# Pred Length: 5, Ref Length: 4
# Pred Length: 4, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 8
# Pred Length: 4, Ref Length: 6
# Pred Length: 8, Ref Length: 6
# Pred Length: 4, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 7, Ref Length: 3
# Pred Length: 6, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 7, Ref Length: 7
# Pred Length: 6, Ref Length: 3
# Pred Length: 8, Ref Length: 4
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 4
# Pred Length: 6, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 6, Ref Length: 7
# Pred Length: 3, Ref Length: 4
# Pred Length: 6, Ref Length: 3
# Pred Length: 5, Ref Length: 3
# Pred Length: 4, Ref Length: 3
# Pred Length: 4, Ref Length: 6
# Pred Length: 5, Ref Length: 6
# Pred Length: 8, Ref Length: 9
# Pred Length: 9, Ref Length: 9
# Pred Length: 3, Ref Length: 4
# Pred Length: 5, Ref Length: 8
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 4
# Pred Length: 7, Ref Length: 7
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 4
# Pred Length: 6, Ref Length: 5
# Pred Length: 3, Ref Length: 4
# Pred Length: 11, Ref Length: 9
# Pred Length: 9, Ref Length: 7
# Pred Length: 7, Ref Length: 6
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 9
# Pred Length: 7, Ref Length: 6
# Pred Length: 4, Ref Length: 6
# Pred Length: 6, Ref Length: 3
# Pred Length: 9, Ref Length: 7
# Pred Length: 6, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 6
# Pred Length: 8, Ref Length: 9
# Pred Length: 8, Ref Length: 6
# Pred Length: 5, Ref Length: 8
# Pred Length: 6, Ref Length: 6
# Pred Length: 8, Ref Length: 7
# Pred Length: 6, Ref Length: 5
# Pred Length: 4, Ref Length: 3
# Pred Length: 8, Ref Length: 7
# Pred Length: 6, Ref Length: 3
# Pred Length: 2, Ref Length: 4
# Pred Length: 6, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 5, Ref Length: 4
# Pred Length: 4, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 7, Ref Length: 8
# Pred Length: 7, Ref Length: 9
# Pred Length: 5, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 7
# Pred Length: 4, Ref Length: 7
# Pred Length: 11, Ref Length: 7
# Pred Length: 7, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 7, Ref Length: 5
# Pred Length: 9, Ref Length: 6
# Pred Length: 9, Ref Length: 8
# Pred Length: 6, Ref Length: 5
# Pred Length: 4, Ref Length: 6
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 7
# Pred Length: 3, Ref Length: 5
# Pred Length: 8, Ref Length: 8
# Pred Length: 8, Ref Length: 8
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 9, Ref Length: 6
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 6
# Pred Length: 8, Ref Length: 5
# Pred Length: 4, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 6
# Pred Length: 7, Ref Length: 4
# Pred Length: 6, Ref Length: 7
# Pred Length: 6, Ref Length: 4
# Pred Length: 5, Ref Length: 6
# Pred Length: 8, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 7, Ref Length: 7
# Pred Length: 7, Ref Length: 4
# Pred Length: 6, Ref Length: 4
# Pred Length: 6, Ref Length: 6
# Pred Length: 4, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 4, Ref Length: 4
# Pred Length: 7, Ref Length: 8
# Pred Length: 5, Ref Length: 6
# Pred Length: 5, Ref Length: 6
# Pred Length: 6, Ref Length: 6
# Pred Length: 4, Ref Length: 7
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 4, Ref Length: 5
# Pred Length: 5, Ref Length: 3
# Pred Length: 3, Ref Length: 5
# Pred Length: 7, Ref Length: 6
# Pred Length: 6, Ref Length: 4
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 7
# Pred Length: 5, Ref Length: 5
# Pred Length: 7, Ref Length: 8
# Pred Length: 6, Ref Length: 6
# Pred Length: 3, Ref Length: 3
# Pred Length: 5, Ref Length: 4
# Pred Length: 11, Ref Length: 4
# Pred Length: 4, Ref Length: 4
# Pred Length: 8, Ref Length: 7
# Pred Length: 7, Ref Length: 7
# Pred Length: 7, Ref Length: 7
# Pred Length: 7, Ref Length: 6
# Pred Length: 5, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 8, Ref Length: 6
# Pred Length: 4, Ref Length: 6
# Pred Length: 7, Ref Length: 7
# Pred Length: 6, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 7, Ref Length: 5
# Pred Length: 6, Ref Length: 4
# Pred Length: 4, Ref Length: 3
# Pred Length: 5, Ref Length: 4
# Pred Length: 7, Ref Length: 5
# Pred Length: 9, Ref Length: 6
# Pred Length: 4, Ref Length: 3
# Pred Length: 4, Ref Length: 4
# Pred Length: 8, Ref Length: 8
# Pred Length: 5, Ref Length: 7
# Pred Length: 7, Ref Length: 4
# Pred Length: 8, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 7, Ref Length: 4
# Pred Length: 4, Ref Length: 4
# Pred Length: 4, Ref Length: 4
# Pred Length: 6, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 7, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 6, Ref Length: 4
# Pred Length: 5, Ref Length: 7
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 6
# Pred Length: 8, Ref Length: 5
# Pred Length: 7, Ref Length: 7
# Pred Length: 5, Ref Length: 5
# Pred Length: 7, Ref Length: 7
# Pred Length: 9, Ref Length: 5
# Pred Length: 8, Ref Length: 6
# Pred Length: 6, Ref Length: 6
# Pred Length: 7, Ref Length: 7
# Pred Length: 9, Ref Length: 3
# Pred Length: 4, Ref Length: 6
# Pred Length: 5, Ref Length: 6
# Pred Length: 7, Ref Length: 9
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 3
# Pred Length: 4, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 8, Ref Length: 5
# Pred Length: 5, Ref Length: 3
# Pred Length: 5, Ref Length: 3
# Pred Length: 4, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 4, Ref Length: 5
# Pred Length: 7, Ref Length: 7
# Pred Length: 7, Ref Length: 5
# Pred Length: 6, Ref Length: 7
# Pred Length: 7, Ref Length: 6
# Pred Length: 4, Ref Length: 5
# Pred Length: 7, Ref Length: 5
# Pred Length: 3, Ref Length: 6
# Pred Length: 5, Ref Length: 10
# Pred Length: 6, Ref Length: 8
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 6
# Pred Length: 8, Ref Length: 9
# Pred Length: 6, Ref Length: 6
# Pred Length: 6, Ref Length: 6
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 8, Ref Length: 7
# Pred Length: 4, Ref Length: 5
# Pred Length: 5, Ref Length: 8
# Pred Length: 5, Ref Length: 4
# Pred Length: 6, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 6, Ref Length: 7
# Pred Length: 6, Ref Length: 4
# Pred Length: 6, Ref Length: 4
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 7
# Pred Length: 4, Ref Length: 4
# Pred Length: 6, Ref Length: 5
# Pred Length: 4, Ref Length: 7
# Pred Length: 4, Ref Length: 9
# Pred Length: 4, Ref Length: 4
# Pred Length: 3, Ref Length: 3
# Pred Length: 7, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 8, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 4
# Pred Length: 7, Ref Length: 4
# Pred Length: 4, Ref Length: 4
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 8
# Pred Length: 5, Ref Length: 6
# Pred Length: 7, Ref Length: 6
# Pred Length: 8, Ref Length: 6
# Pred Length: 8, Ref Length: 6
# Pred Length: 9, Ref Length: 10
# Pred Length: 6, Ref Length: 7
# Pred Length: 8, Ref Length: 7
# Pred Length: 3, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 4
# Pred Length: 8, Ref Length: 6
# Pred Length: 4, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 7, Ref Length: 6
# Pred Length: 6, Ref Length: 4
# Pred Length: 5, Ref Length: 7
# Pred Length: 4, Ref Length: 6
# Pred Length: 4, Ref Length: 3
# Pred Length: 6, Ref Length: 9
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 6
# Pred Length: 7, Ref Length: 4
# Pred Length: 5, Ref Length: 6
# Pred Length: 9, Ref Length: 9
# Pred Length: 7, Ref Length: 6
# Pred Length: 5, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 7, Ref Length: 8
# Pred Length: 6, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 6
# Pred Length: 5, Ref Length: 4
# Pred Length: 8, Ref Length: 9
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 8
# Pred Length: 6, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 9, Ref Length: 6
# Pred Length: 11, Ref Length: 9
# Pred Length: 3, Ref Length: 5
# Pred Length: 8, Ref Length: 7
# Pred Length: 5, Ref Length: 6
# Pred Length: 5, Ref Length: 6
# Pred Length: 6, Ref Length: 8
# Pred Length: 8, Ref Length: 6
# Pred Length: 5, Ref Length: 6
# Pred Length: 3, Ref Length: 4
# Pred Length: 6, Ref Length: 5
# Pred Length: 3, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 6
# Pred Length: 3, Ref Length: 4
# Pred Length: 6, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 7, Ref Length: 8
# Pred Length: 7, Ref Length: 6
# Pred Length: 5, Ref Length: 4
# Pred Length: 7, Ref Length: 4
# Pred Length: 6, Ref Length: 6
# Pred Length: 8, Ref Length: 6
# Pred Length: 4, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 3, Ref Length: 5
# Pred Length: 11, Ref Length: 10
# Pred Length: 7, Ref Length: 7
# Pred Length: 3, Ref Length: 5
# Pred Length: 14, Ref Length: 5
# Pred Length: 4, Ref Length: 7
# Pred Length: 6, Ref Length: 6
# Pred Length: 4, Ref Length: 5
# Pred Length: 3, Ref Length: 5
# Pred Length: 6, Ref Length: 7
# Pred Length: 2, Ref Length: 3
# Pred Length: 6, Ref Length: 3
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 5, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 8, Ref Length: 6
# Pred Length: 4, Ref Length: 5
# Pred Length: 6, Ref Length: 7
# Pred Length: 4, Ref Length: 5
# Pred Length: 5, Ref Length: 4
# Pred Length: 7, Ref Length: 7
# Pred Length: 7, Ref Length: 10
# Pred Length: 5, Ref Length: 3
# Pred Length: 5, Ref Length: 4
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 4
# Pred Length: 5, Ref Length: 7
# Pred Length: 7, Ref Length: 9
# Pred Length: 3, Ref Length: 3
# Pred Length: 7, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 7, Ref Length: 4
# Pred Length: 5, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 9, Ref Length: 7
# Pred Length: 6, Ref Length: 4
# Pred Length: 6, Ref Length: 7
# Pred Length: 5, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 5
# Pred Length: 6, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 3, Ref Length: 7
# Pred Length: 5, Ref Length: 7
# Pred Length: 7, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 7
# Pred Length: 4, Ref Length: 3
# Pred Length: 6, Ref Length: 7
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 8
# Pred Length: 6, Ref Length: 6
# Pred Length: 6, Ref Length: 6
# Pred Length: 4, Ref Length: 6
# Pred Length: 5, Ref Length: 3
# Pred Length: 6, Ref Length: 4
# Pred Length: 6, Ref Length: 6
# Pred Length: 8, Ref Length: 4
# Pred Length: 9, Ref Length: 8
# Pred Length: 8, Ref Length: 7
# Pred Length: 4, Ref Length: 4
# Pred Length: 6, Ref Length: 6
# Pred Length: 7, Ref Length: 5
# Pred Length: 6, Ref Length: 8
# Pred Length: 4, Ref Length: 7
# Pred Length: 4, Ref Length: 6
# Pred Length: 6, Ref Length: 8
# Pred Length: 8, Ref Length: 8
# Pred Length: 5, Ref Length: 5
# Pred Length: 7, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 3, Ref Length: 4
# Pred Length: 7, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 8, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 3, Ref Length: 4
# Pred Length: 5, Ref Length: 7
# Pred Length: 4, Ref Length: 4
# Pred Length: 8, Ref Length: 6
# Pred Length: 6, Ref Length: 4
# Pred Length: 3, Ref Length: 7
# Pred Length: 9, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 8, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 3
# Pred Length: 5, Ref Length: 4
# Pred Length: 7, Ref Length: 7
# Pred Length: 6, Ref Length: 7
# Pred Length: 6, Ref Length: 7
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 7, Ref Length: 6
# Pred Length: 6, Ref Length: 6
# Pred Length: 4, Ref Length: 7
# Pred Length: 5, Ref Length: 6
# Pred Length: 7, Ref Length: 8
# Pred Length: 10, Ref Length: 5
# Pred Length: 10, Ref Length: 9
# Pred Length: 4, Ref Length: 7
# Pred Length: 4, Ref Length: 6
# Pred Length: 6, Ref Length: 6
# Pred Length: 6, Ref Length: 3
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 5
# Pred Length: 8, Ref Length: 7
# Pred Length: 6, Ref Length: 7
# Pred Length: 7, Ref Length: 6
# Pred Length: 5, Ref Length: 6
# Pred Length: 6, Ref Length: 3
# Pred Length: 5, Ref Length: 5
# Pred Length: 10, Ref Length: 9
# Pred Length: 5, Ref Length: 6
# Pred Length: 7, Ref Length: 7
# Pred Length: 7, Ref Length: 7
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 3
# Pred Length: 6, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 4, Ref Length: 5
# Pred Length: 7, Ref Length: 7
# Pred Length: 6, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 3, Ref Length: 3
# Pred Length: 6, Ref Length: 7
# Pred Length: 8, Ref Length: 6
# Pred Length: 4, Ref Length: 4
# Pred Length: 7, Ref Length: 8
# Pred Length: 7, Ref Length: 6
# Pred Length: 4, Ref Length: 5
# Pred Length: 4, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 6
# Pred Length: 4, Ref Length: 8
# Pred Length: 7, Ref Length: 6
# Pred Length: 4, Ref Length: 5
# Pred Length: 8, Ref Length: 6
# Pred Length: 3, Ref Length: 5
# Pred Length: 5, Ref Length: 4
# Pred Length: 7, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 7, Ref Length: 6
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 6, Ref Length: 7
# Pred Length: 9, Ref Length: 8
# Pred Length: 5, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 7, Ref Length: 8
# Pred Length: 5, Ref Length: 6
# Pred Length: 4, Ref Length: 3
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 7, Ref Length: 4
# Pred Length: 6, Ref Length: 8
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 3
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 10, Ref Length: 5
# Pred Length: 6, Ref Length: 4
# Pred Length: 7, Ref Length: 6
# Pred Length: 9, Ref Length: 5
# Pred Length: 7, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 3
# Pred Length: 6, Ref Length: 10
# Pred Length: 7, Ref Length: 7
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 4
# Pred Length: 7, Ref Length: 6
# Pred Length: 5, Ref Length: 6
# Pred Length: 5, Ref Length: 9
# Pred Length: 5, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 8, Ref Length: 8
# Pred Length: 6, Ref Length: 5
# Pred Length: 4, Ref Length: 7
# Pred Length: 4, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 9, Ref Length: 7
# Pred Length: 6, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 8, Ref Length: 7
# Pred Length: 5, Ref Length: 3
# Pred Length: 5, Ref Length: 4
# Pred Length: 4, Ref Length: 4
# Pred Length: 6, Ref Length: 3
# Pred Length: 5, Ref Length: 4
# Pred Length: 3, Ref Length: 5
# Pred Length: 4, Ref Length: 5
# Pred Length: 5, Ref Length: 4
# Pred Length: 7, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 4, Ref Length: 4
# Pred Length: 8, Ref Length: 6
# Pred Length: 4, Ref Length: 4
# Pred Length: 4, Ref Length: 6
# Pred Length: 7, Ref Length: 7
# Pred Length: 5, Ref Length: 6
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 3, Ref Length: 5
# Pred Length: 6, Ref Length: 9
# Pred Length: 7, Ref Length: 8
# Pred Length: 8, Ref Length: 6
# Pred Length: 8, Ref Length: 5
# Pred Length: 7, Ref Length: 8
# Pred Length: 4, Ref Length: 7
# Pred Length: 6, Ref Length: 4
# Pred Length: 3, Ref Length: 5
# Pred Length: 5, Ref Length: 7
# Pred Length: 6, Ref Length: 3
# Pred Length: 4, Ref Length: 5
# Pred Length: 7, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 10, Ref Length: 8
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 4
# Pred Length: 6, Ref Length: 6
# Pred Length: 7, Ref Length: 6
# Pred Length: 7, Ref Length: 4
# Pred Length: 5, Ref Length: 8
# Pred Length: 7, Ref Length: 8
# Pred Length: 5, Ref Length: 3
# Pred Length: 5, Ref Length: 3
# Pred Length: 6, Ref Length: 9
# Pred Length: 3, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 8
# Pred Length: 8, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 7
# Pred Length: 5, Ref Length: 4
# Pred Length: 7, Ref Length: 9
# Pred Length: 9, Ref Length: 6
# Pred Length: 6, Ref Length: 6
# Pred Length: 3, Ref Length: 4
# Pred Length: 10, Ref Length: 7
# Pred Length: 6, Ref Length: 8
# Pred Length: 7, Ref Length: 7
# Pred Length: 6, Ref Length: 7
# Pred Length: 10, Ref Length: 8
# Pred Length: 4, Ref Length: 5
# Pred Length: 4, Ref Length: 6
# Pred Length: 6, Ref Length: 6
# Pred Length: 4, Ref Length: 6
# Pred Length: 5, Ref Length: 7
# Pred Length: 4, Ref Length: 5
# Pred Length: 5, Ref Length: 6
# Pred Length: 3, Ref Length: 3
# Pred Length: 4, Ref Length: 3
# Pred Length: 4, Ref Length: 8
# Pred Length: 7, Ref Length: 6
# Pred Length: 4, Ref Length: 7
# Pred Length: 4, Ref Length: 7
# Pred Length: 7, Ref Length: 5
# Pred Length: 5, Ref Length: 6
# Pred Length: 5, Ref Length: 9
# Pred Length: 3, Ref Length: 4
# Pred Length: 8, Ref Length: 8
# Pred Length: 4, Ref Length: 6
# Pred Length: 7, Ref Length: 7
# Pred Length: 5, Ref Length: 5
# Pred Length: 2, Ref Length: 5
# Pred Length: 7, Ref Length: 3
# Pred Length: 6, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 7, Ref Length: 6
# Pred Length: 8, Ref Length: 8
# Pred Length: 5, Ref Length: 6
# Pred Length: 6, Ref Length: 8
# Pred Length: 4, Ref Length: 6
# Pred Length: 7, Ref Length: 12
# Pred Length: 3, Ref Length: 7
# Pred Length: 7, Ref Length: 7
# Pred Length: 8, Ref Length: 8
# Pred Length: 4, Ref Length: 5
# Pred Length: 7, Ref Length: 7
# Pred Length: 3, Ref Length: 5
# Pred Length: 8, Ref Length: 5
# Pred Length: 7, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 4, Ref Length: 6
# Pred Length: 7, Ref Length: 7
# Pred Length: 5, Ref Length: 7
# Pred Length: 5, Ref Length: 8
# Pred Length: 4, Ref Length: 6
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 8
# Pred Length: 5, Ref Length: 4
# Pred Length: 7, Ref Length: 9
# Pred Length: 8, Ref Length: 7
# Pred Length: 6, Ref Length: 5
# Pred Length: 6, Ref Length: 4
# Pred Length: 8, Ref Length: 8
# Pred Length: 7, Ref Length: 6
# Pred Length: 6, Ref Length: 11
# Pred Length: 6, Ref Length: 3
# Pred Length: 5, Ref Length: 9
# Pred Length: 7, Ref Length: 6
# Pred Length: 5, Ref Length: 6
# Pred Length: 8, Ref Length: 8
# Pred Length: 5, Ref Length: 6
# Pred Length: 6, Ref Length: 7
# Pred Length: 6, Ref Length: 5
# Pred Length: 10, Ref Length: 9
# Pred Length: 5, Ref Length: 4
# Pred Length: 5, Ref Length: 6
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 4, Ref Length: 7
# Pred Length: 6, Ref Length: 4
# Pred Length: 5, Ref Length: 8
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 3
# Pred Length: 6, Ref Length: 5
# Pred Length: 8, Ref Length: 7
# Pred Length: 3, Ref Length: 4
# Pred Length: 3, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 7, Ref Length: 6
# Pred Length: 6, Ref Length: 9
# Pred Length: 6, Ref Length: 6
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 5
# Pred Length: 7, Ref Length: 8
# Pred Length: 4, Ref Length: 7
# Pred Length: 4, Ref Length: 5
# Pred Length: 6, Ref Length: 3
# Pred Length: 9, Ref Length: 6
# Pred Length: 6, Ref Length: 6
# Pred Length: 4, Ref Length: 7
# Pred Length: 5, Ref Length: 7
# Pred Length: 7, Ref Length: 10
# Pred Length: 5, Ref Length: 4
# Pred Length: 8, Ref Length: 6
# Pred Length: 5, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 6, Ref Length: 7
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 8, Ref Length: 8
# Pred Length: 8, Ref Length: 9
# Pred Length: 3, Ref Length: 3
# Pred Length: 4, Ref Length: 7
# Pred Length: 3, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 7
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 7
# Pred Length: 5, Ref Length: 8
# Pred Length: 6, Ref Length: 4
# Pred Length: 11, Ref Length: 7
# Pred Length: 3, Ref Length: 3
# Pred Length: 7, Ref Length: 3
# Pred Length: 7, Ref Length: 8
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 7
# Pred Length: 5, Ref Length: 5
# Pred Length: 9, Ref Length: 7
# Pred Length: 8, Ref Length: 5
# Pred Length: 6, Ref Length: 7
# Pred Length: 2, Ref Length: 4
# Pred Length: 8, Ref Length: 8
# Pred Length: 3, Ref Length: 6
# Pred Length: 4, Ref Length: 6
# Pred Length: 6, Ref Length: 10
# Pred Length: 4, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 3, Ref Length: 3
# Pred Length: 12, Ref Length: 6
# Pred Length: 4, Ref Length: 4
# Pred Length: 6, Ref Length: 4
# Pred Length: 3, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 4, Ref Length: 5
# Pred Length: 5, Ref Length: 3
# Pred Length: 4, Ref Length: 4
# Pred Length: 7, Ref Length: 6
# Pred Length: 6, Ref Length: 8
# Pred Length: 4, Ref Length: 7
# Pred Length: 4, Ref Length: 5
# Pred Length: 6, Ref Length: 8
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 7, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 3, Ref Length: 4
# Pred Length: 8, Ref Length: 6
# Pred Length: 7, Ref Length: 7
# Pred Length: 7, Ref Length: 5
# Pred Length: 4, Ref Length: 5
# Pred Length: 6, Ref Length: 4
# Pred Length: 7, Ref Length: 7
# Pred Length: 5, Ref Length: 4
# Pred Length: 5, Ref Length: 7
# Pred Length: 3, Ref Length: 5
# Pred Length: 7, Ref Length: 7
# Pred Length: 6, Ref Length: 7
# Pred Length: 10, Ref Length: 8
# Pred Length: 7, Ref Length: 3
# Pred Length: 7, Ref Length: 6
# Pred Length: 6, Ref Length: 7
# Pred Length: 5, Ref Length: 8
# Pred Length: 5, Ref Length: 4
# Pred Length: 9, Ref Length: 7
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 5
# Pred Length: 5, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 3
# Pred Length: 6, Ref Length: 6
# Pred Length: 3, Ref Length: 4
# Pred Length: 5, Ref Length: 7
# Pred Length: 7, Ref Length: 7
# Pred Length: 11, Ref Length: 7
# Pred Length: 4, Ref Length: 4
# Pred Length: 8, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 8
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 7, Ref Length: 9
# Pred Length: 6, Ref Length: 6
# Pred Length: 7, Ref Length: 6
# Pred Length: 4, Ref Length: 4
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 4
# Pred Length: 6, Ref Length: 6
# Pred Length: 4, Ref Length: 5
# Pred Length: 8, Ref Length: 6
# Pred Length: 5, Ref Length: 3
# Pred Length: 6, Ref Length: 7
# Pred Length: 6, Ref Length: 6
# Pred Length: 4, Ref Length: 6
# Pred Length: 5, Ref Length: 6
# Pred Length: 7, Ref Length: 6
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 6
# Pred Length: 8, Ref Length: 6
# Pred Length: 4, Ref Length: 4
# Pred Length: 7, Ref Length: 7
# Pred Length: 6, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 6, Ref Length: 4
# Pred Length: 10, Ref Length: 8
# Pred Length: 4, Ref Length: 5
# Pred Length: 7, Ref Length: 7
# Pred Length: 6, Ref Length: 7
# Pred Length: 5, Ref Length: 9
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 7
# Pred Length: 6, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 8, Ref Length: 6
# Pred Length: 4, Ref Length: 6
# Pred Length: 8, Ref Length: 7
# Pred Length: 8, Ref Length: 8
# Pred Length: 4, Ref Length: 4
# Pred Length: 7, Ref Length: 7
# Pred Length: 5, Ref Length: 4
# Pred Length: 7, Ref Length: 5
# Pred Length: 8, Ref Length: 7
# Pred Length: 4, Ref Length: 4
# Pred Length: 4, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 6, Ref Length: 3
# Pred Length: 7, Ref Length: 8
# Pred Length: 8, Ref Length: 4
# Pred Length: 8, Ref Length: 8
# Pred Length: 9, Ref Length: 5
# Pred Length: 6, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 5, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 7, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 7, Ref Length: 5
# Pred Length: 5, Ref Length: 4
# Pred Length: 6, Ref Length: 6
# Pred Length: 3, Ref Length: 3
# Pred Length: 7, Ref Length: 5
# Pred Length: 3, Ref Length: 3
# Pred Length: 5, Ref Length: 4
# Pred Length: 4, Ref Length: 4
# Pred Length: 4, Ref Length: 4
# Pred Length: 8, Ref Length: 4
# Pred Length: 6, Ref Length: 7
# Pred Length: 7, Ref Length: 6
# Pred Length: 4, Ref Length: 6
# Pred Length: 6, Ref Length: 4
# Pred Length: 3, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 9
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 8
# Pred Length: 5, Ref Length: 6
# Pred Length: 9, Ref Length: 5
# Pred Length: 8, Ref Length: 7
# Pred Length: 6, Ref Length: 6
# Pred Length: 10, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 8, Ref Length: 6
# Pred Length: 4, Ref Length: 6
# Pred Length: 5, Ref Length: 6
# Pred Length: 7, Ref Length: 7
# Pred Length: 4, Ref Length: 6
# Pred Length: 7, Ref Length: 6
# Pred Length: 8, Ref Length: 6
# Pred Length: 8, Ref Length: 7
# Pred Length: 6, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 7, Ref Length: 4
# Pred Length: 3, Ref Length: 4
# Pred Length: 6, Ref Length: 8
# Pred Length: 5, Ref Length: 4
# Pred Length: 7, Ref Length: 8
# Pred Length: 2, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 8, Ref Length: 9
# Pred Length: 7, Ref Length: 8
# Pred Length: 4, Ref Length: 5
# Pred Length: 7, Ref Length: 7
# Pred Length: 5, Ref Length: 6
# Pred Length: 3, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 9, Ref Length: 6
# Pred Length: 6, Ref Length: 6
# Pred Length: 3, Ref Length: 3
# Pred Length: 4, Ref Length: 5
# Pred Length: 4, Ref Length: 8
# Pred Length: 7, Ref Length: 8
# Pred Length: 7, Ref Length: 6
# Pred Length: 7, Ref Length: 7
# Pred Length: 6, Ref Length: 8
# Pred Length: 5, Ref Length: 3
# Pred Length: 7, Ref Length: 5
# Pred Length: 7, Ref Length: 7
# Pred Length: 8, Ref Length: 7
# Pred Length: 8, Ref Length: 7
# Pred Length: 4, Ref Length: 3
# Pred Length: 4, Ref Length: 4
# Pred Length: 6, Ref Length: 6
# Pred Length: 4, Ref Length: 4
# Pred Length: 6, Ref Length: 7
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 4
# Pred Length: 4, Ref Length: 6
# Pred Length: 8, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 6, Ref Length: 3
# Pred Length: 5, Ref Length: 4
# Pred Length: 7, Ref Length: 8
# Pred Length: 7, Ref Length: 7
# Pred Length: 4, Ref Length: 4
# Pred Length: 3, Ref Length: 3
# Pred Length: 4, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 7
# Pred Length: 5, Ref Length: 7
# Pred Length: 7, Ref Length: 9
# Pred Length: 5, Ref Length: 4
# Pred Length: 5, Ref Length: 8
# Pred Length: 5, Ref Length: 4
# Pred Length: 6, Ref Length: 7
# Pred Length: 8, Ref Length: 7
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 7
# Pred Length: 5, Ref Length: 8
# Pred Length: 6, Ref Length: 7
# Pred Length: 6, Ref Length: 4
# Pred Length: 3, Ref Length: 6
# Pred Length: 5, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 8, Ref Length: 7
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 9, Ref Length: 4
# Pred Length: 8, Ref Length: 6
# Pred Length: 3, Ref Length: 5
# Pred Length: 9, Ref Length: 6
# Pred Length: 9, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 6
# Pred Length: 6, Ref Length: 7
# Pred Length: 7, Ref Length: 8
# Pred Length: 9, Ref Length: 7
# Pred Length: 6, Ref Length: 6
# Pred Length: 7, Ref Length: 6
# Pred Length: 6, Ref Length: 8
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 5
# Pred Length: 7, Ref Length: 7
# Pred Length: 5, Ref Length: 4
# Pred Length: 6, Ref Length: 7
# Pred Length: 8, Ref Length: 5
# Pred Length: 8, Ref Length: 4
# Pred Length: 8, Ref Length: 6
# Pred Length: 7, Ref Length: 7
# Pred Length: 7, Ref Length: 8
# Pred Length: 4, Ref Length: 3
# Pred Length: 7, Ref Length: 6
# Pred Length: 4, Ref Length: 7
# Pred Length: 6, Ref Length: 7
# Pred Length: 4, Ref Length: 4
# Pred Length: 7, Ref Length: 6
# Pred Length: 6, Ref Length: 8
# Pred Length: 4, Ref Length: 4
# Pred Length: 7, Ref Length: 5
# Pred Length: 5, Ref Length: 6
# Pred Length: 5, Ref Length: 4
# Pred Length: 9, Ref Length: 7
# Pred Length: 10, Ref Length: 6
# Pred Length: 5, Ref Length: 3
# Pred Length: 5, Ref Length: 4
# Pred Length: 5, Ref Length: 9
# Pred Length: 4, Ref Length: 5
# Pred Length: 6, Ref Length: 7
# Pred Length: 7, Ref Length: 6
# Pred Length: 5, Ref Length: 4
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 4
# Pred Length: 6, Ref Length: 4
# Pred Length: 5, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 6
# Pred Length: 7, Ref Length: 6
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 6
# Pred Length: 8, Ref Length: 6
# Pred Length: 4, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 7
# Pred Length: 7, Ref Length: 8
# Pred Length: 6, Ref Length: 4
# Pred Length: 10, Ref Length: 7
# Pred Length: 3, Ref Length: 6
# Pred Length: 5, Ref Length: 6
# Pred Length: 8, Ref Length: 7
# Pred Length: 5, Ref Length: 5
# Pred Length: 7, Ref Length: 7
# Pred Length: 9, Ref Length: 6
# Pred Length: 7, Ref Length: 7
# Pred Length: 8, Ref Length: 5
# Pred Length: 6, Ref Length: 7
# Pred Length: 7, Ref Length: 6
# Pred Length: 6, Ref Length: 6
# Pred Length: 9, Ref Length: 5
# Pred Length: 4, Ref Length: 7
# Pred Length: 7, Ref Length: 11
# Pred Length: 5, Ref Length: 3
# Pred Length: 3, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 4, Ref Length: 4
# Pred Length: 10, Ref Length: 5
# Pred Length: 4, Ref Length: 7
# Pred Length: 6, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 6, Ref Length: 7
# Pred Length: 4, Ref Length: 4
# Pred Length: 7, Ref Length: 5
# Pred Length: 3, Ref Length: 6
# Pred Length: 10, Ref Length: 4
# Pred Length: 6, Ref Length: 4
# Pred Length: 3, Ref Length: 5
# Pred Length: 4, Ref Length: 6
# Pred Length: 5, Ref Length: 4
# Pred Length: 6, Ref Length: 4
# Pred Length: 9, Ref Length: 6
# Pred Length: 8, Ref Length: 3
# Pred Length: 10, Ref Length: 7
# Pred Length: 4, Ref Length: 5
# Pred Length: 5, Ref Length: 7
# Pred Length: 4, Ref Length: 4
# Pred Length: 6, Ref Length: 7
# Pred Length: 4, Ref Length: 6
# Pred Length: 4, Ref Length: 4
# Pred Length: 6, Ref Length: 6
# Pred Length: 8, Ref Length: 6
# Pred Length: 5, Ref Length: 4
# Pred Length: 7, Ref Length: 5
# Pred Length: 5, Ref Length: 4
# Pred Length: 5, Ref Length: 4
# Pred Length: 5, Ref Length: 4
# Pred Length: 3, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 8, Ref Length: 9
# Pred Length: 4, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 7, Ref Length: 7
# Pred Length: 4, Ref Length: 6
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 7
# Pred Length: 6, Ref Length: 7
# Pred Length: 8, Ref Length: 8
# Pred Length: 5, Ref Length: 7
# Pred Length: 4, Ref Length: 6
# Pred Length: 4, Ref Length: 6
# Pred Length: 7, Ref Length: 8
# Pred Length: 8, Ref Length: 8
# Pred Length: 8, Ref Length: 8
# Pred Length: 4, Ref Length: 6
# Pred Length: 6, Ref Length: 6
# Pred Length: 7, Ref Length: 6
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 8
# Pred Length: 5, Ref Length: 7
# Pred Length: 7, Ref Length: 7
# Pred Length: 9, Ref Length: 9
# Pred Length: 6, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 4, Ref Length: 6
# Pred Length: 8, Ref Length: 7
# Pred Length: 7, Ref Length: 6
# Pred Length: 3, Ref Length: 4
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 4
# Pred Length: 3, Ref Length: 3
# Pred Length: 4, Ref Length: 6
# Pred Length: 6, Ref Length: 6
# Pred Length: 6, Ref Length: 7
# Pred Length: 7, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 7
# Pred Length: 8, Ref Length: 4
# Pred Length: 9, Ref Length: 9
# Pred Length: 4, Ref Length: 5
# Pred Length: 4, Ref Length: 3
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 6
# Pred Length: 4, Ref Length: 5
# Pred Length: 11, Ref Length: 8
# Pred Length: 5, Ref Length: 8
# Pred Length: 8, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 3, Ref Length: 5
# Pred Length: 7, Ref Length: 7
# Pred Length: 8, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 7
# Pred Length: 6, Ref Length: 7
# Pred Length: 7, Ref Length: 7
# Pred Length: 5, Ref Length: 4
# Pred Length: 4, Ref Length: 3
# Pred Length: 6, Ref Length: 7
# Pred Length: 4, Ref Length: 3
# Pred Length: 9, Ref Length: 3
# Pred Length: 4, Ref Length: 4
# Pred Length: 4, Ref Length: 3
# Pred Length: 5, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 4, Ref Length: 5
# Pred Length: 8, Ref Length: 7
# Pred Length: 7, Ref Length: 6
# Pred Length: 4, Ref Length: 6
# Pred Length: 3, Ref Length: 4
# Pred Length: 5, Ref Length: 8
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 7, Ref Length: 5
# Pred Length: 5, Ref Length: 3
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 6
# Pred Length: 5, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 7, Ref Length: 6
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 4
# Pred Length: 6, Ref Length: 5
# Pred Length: 7, Ref Length: 8
# Pred Length: 7, Ref Length: 6
# Pred Length: 5, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 6, Ref Length: 5
# Pred Length: 4, Ref Length: 5
# Pred Length: 5, Ref Length: 4
# Pred Length: 5, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 8
# Pred Length: 3, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 8, Ref Length: 7
# Pred Length: 6, Ref Length: 8
# Pred Length: 5, Ref Length: 4
# Pred Length: 6, Ref Length: 4
# Pred Length: 7, Ref Length: 7
# Pred Length: 6, Ref Length: 5
# Pred Length: 10, Ref Length: 4
# Pred Length: 7, Ref Length: 6
# Pred Length: 8, Ref Length: 7
# Pred Length: 8, Ref Length: 10
# Pred Length: 4, Ref Length: 4
# Pred Length: 7, Ref Length: 4
# Pred Length: 9, Ref Length: 9
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 8, Ref Length: 8
# Pred Length: 5, Ref Length: 4
# Pred Length: 4, Ref Length: 6
# Pred Length: 4, Ref Length: 5
# Pred Length: 5, Ref Length: 3
# Pred Length: 5, Ref Length: 5
# Pred Length: 3, Ref Length: 5
# Pred Length: 5, Ref Length: 4
# Pred Length: 9, Ref Length: 9
# Pred Length: 5, Ref Length: 4
# Pred Length: 4, Ref Length: 9
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 7, Ref Length: 6
# Pred Length: 3, Ref Length: 3
# Pred Length: 6, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 7, Ref Length: 4
# Pred Length: 5, Ref Length: 6
# Pred Length: 5, Ref Length: 4
# Pred Length: 6, Ref Length: 5
# Pred Length: 7, Ref Length: 6
# Pred Length: 3, Ref Length: 6
# Pred Length: 4, Ref Length: 5
# Pred Length: 4, Ref Length: 3
# Pred Length: 6, Ref Length: 5
# Pred Length: 7, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 4
# Pred Length: 6, Ref Length: 7
# Pred Length: 5, Ref Length: 5
# Pred Length: 9, Ref Length: 7
# Pred Length: 5, Ref Length: 4
# Pred Length: 6, Ref Length: 6
# Pred Length: 7, Ref Length: 6
# Pred Length: 6, Ref Length: 3
# Pred Length: 6, Ref Length: 7
# Pred Length: 7, Ref Length: 7
# Pred Length: 4, Ref Length: 4
# Pred Length: 8, Ref Length: 7
# Pred Length: 7, Ref Length: 7
# Pred Length: 9, Ref Length: 3
# Pred Length: 2, Ref Length: 5
# Pred Length: 7, Ref Length: 9
# Pred Length: 3, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 7
# Pred Length: 5, Ref Length: 6
# Pred Length: 8, Ref Length: 6
# Pred Length: 12, Ref Length: 8
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 4
# Pred Length: 9, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 6
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 8
# Pred Length: 5, Ref Length: 5
# Pred Length: 8, Ref Length: 7
# Pred Length: 5, Ref Length: 6
# Pred Length: 5, Ref Length: 7
# Pred Length: 7, Ref Length: 9
# Pred Length: 6, Ref Length: 7
# Pred Length: 4, Ref Length: 4
# Pred Length: 4, Ref Length: 6
# Pred Length: 4, Ref Length: 6
# Pred Length: 9, Ref Length: 7
# Pred Length: 3, Ref Length: 5
# Pred Length: 6, Ref Length: 4
# Pred Length: 8, Ref Length: 9
# Pred Length: 7, Ref Length: 6
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 7
# Pred Length: 10, Ref Length: 8
# Pred Length: 4, Ref Length: 4
# Pred Length: 8, Ref Length: 4
# Pred Length: 4, Ref Length: 8
# Pred Length: 6, Ref Length: 3
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 6
# Pred Length: 5, Ref Length: 8
# Pred Length: 3, Ref Length: 6
# Pred Length: 2, Ref Length: 5
# Pred Length: 2, Ref Length: 5
# Pred Length: 5, Ref Length: 7
# Pred Length: 5, Ref Length: 6
# Pred Length: 6, Ref Length: 9
# Pred Length: 9, Ref Length: 7
# Pred Length: 4, Ref Length: 5
# Pred Length: 4, Ref Length: 7
# Pred Length: 4, Ref Length: 6
# Pred Length: 5, Ref Length: 7
# Pred Length: 4, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 5, Ref Length: 8
# Pred Length: 4, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 10, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 6, Ref Length: 6
# Pred Length: 8, Ref Length: 4
# Pred Length: 6, Ref Length: 8
# Pred Length: 7, Ref Length: 6
# Pred Length: 6, Ref Length: 7
# Pred Length: 6, Ref Length: 7
# Pred Length: 5, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 4
# Pred Length: 6, Ref Length: 8
# Pred Length: 7, Ref Length: 7
# Pred Length: 7, Ref Length: 7
# Pred Length: 6, Ref Length: 7
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 3
# Pred Length: 5, Ref Length: 5
# Pred Length: 7, Ref Length: 6
# Pred Length: 6, Ref Length: 4
# Pred Length: 7, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 3
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 6
# Pred Length: 6, Ref Length: 6
# Pred Length: 3, Ref Length: 3
# Pred Length: 5, Ref Length: 6
# Pred Length: 6, Ref Length: 4
# Pred Length: 7, Ref Length: 6
# Pred Length: 3, Ref Length: 4
# Pred Length: 4, Ref Length: 7
# Pred Length: 8, Ref Length: 7
# Pred Length: 5, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 6
# Pred Length: 4, Ref Length: 8
# Pred Length: 8, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 8
# Pred Length: 4, Ref Length: 3
# Pred Length: 6, Ref Length: 5
# Pred Length: 3, Ref Length: 8
# Pred Length: 6, Ref Length: 6
# Pred Length: 6, Ref Length: 7
# Pred Length: 8, Ref Length: 6
# Pred Length: 9, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 8
# Pred Length: 8, Ref Length: 12
# Pred Length: 4, Ref Length: 6
# Pred Length: 5, Ref Length: 3
# Pred Length: 7, Ref Length: 5
# Pred Length: 7, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 6
# Pred Length: 8, Ref Length: 9
# Pred Length: 9, Ref Length: 6
# Pred Length: 7, Ref Length: 6
# Pred Length: 7, Ref Length: 8
# Pred Length: 8, Ref Length: 8
# Pred Length: 7, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# ...
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 3, Ref Length: 4
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 4
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 7, Ref Length: 8
# Pred Length: 5, Ref Length: 6
# Pred Length: 4, Ref Length: 5
# Pred Length: 7, Ref Length: 6
# Pred Length: 4, Ref Length: 10
# Pred Length: 5, Ref Length: 7
# Pred Length: 7, Ref Length: 6
# Pred Length: 6, Ref Length: 8
# Pred Length: 10, Ref Length: 9
# Pred Length: 9, Ref Length: 4
# Pred Length: 4, Ref Length: 4
# Pred Length: 3, Ref Length: 5
# Pred Length: 5, Ref Length: 3
# Pred Length: 3, Ref Length: 3
# Pred Length: 10, Ref Length: 6
# Pred Length: 9, Ref Length: 7
# Pred Length: 7, Ref Length: 7
# Pred Length: 4, Ref Length: 5
# Pred Length: 8, Ref Length: 6
# Pred Length: 5, Ref Length: 4
# Pred Length: 5, Ref Length: 6
# Pred Length: 9, Ref Length: 7
# Pred Length: 6, Ref Length: 10
# Pred Length: 3, Ref Length: 3
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 7, Ref Length: 7
# Pred Length: 5, Ref Length: 6
# Pred Length: 5, Ref Length: 6
# Pred Length: 10, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 3, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 8, Ref Length: 7
# Pred Length: 4, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 3
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 7
# Pred Length: 7, Ref Length: 6
# Pred Length: 4, Ref Length: 3
# Pred Length: 5, Ref Length: 6
# Pred Length: 9, Ref Length: 6
# Pred Length: 4, Ref Length: 5
# Pred Length: 7, Ref Length: 6
# Pred Length: 4, Ref Length: 6
# Pred Length: 3, Ref Length: 5
# Pred Length: 4, Ref Length: 3
# Pred Length: 7, Ref Length: 6
# Pred Length: 5, Ref Length: 8
# Pred Length: 4, Ref Length: 6
# Pred Length: 6, Ref Length: 7
# Pred Length: 8, Ref Length: 7
# Pred Length: 4, Ref Length: 4
# Pred Length: 8, Ref Length: 5
# Pred Length: 4, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 6, Ref Length: 5
# Pred Length: 4, Ref Length: 3
# Pred Length: 5, Ref Length: 4
# Pred Length: 7, Ref Length: 9
# Pred Length: 6, Ref Length: 8
# Pred Length: 5, Ref Length: 3
# Pred Length: 8, Ref Length: 9
# Pred Length: 9, Ref Length: 6
# Pred Length: 6, Ref Length: 7
# Pred Length: 5, Ref Length: 6
# Pred Length: 7, Ref Length: 6
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 6
# Pred Length: 7, Ref Length: 7
# Pred Length: 4, Ref Length: 4
# Pred Length: 6, Ref Length: 3
# Pred Length: 5, Ref Length: 3
# Pred Length: 5, Ref Length: 6
# Pred Length: 5, Ref Length: 4
# Pred Length: 3, Ref Length: 6
# Pred Length: 6, Ref Length: 4
# Pred Length: 3, Ref Length: 4
# Pred Length: 2, Ref Length: 5
# Pred Length: 3, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 3, Ref Length: 6
# Pred Length: 8, Ref Length: 8
# Pred Length: 4, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 3, Ref Length: 4
# Pred Length: 6, Ref Length: 4
# Pred Length: 8, Ref Length: 9
# Pred Length: 7, Ref Length: 5
# Pred Length: 9, Ref Length: 6
# Pred Length: 3, Ref Length: 3
# Pred Length: 5, Ref Length: 8
# Pred Length: 5, Ref Length: 4
# Pred Length: 6, Ref Length: 7
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 9, Ref Length: 8
# Pred Length: 6, Ref Length: 7
# Pred Length: 8, Ref Length: 4
# Pred Length: 7, Ref Length: 6
# Pred Length: 6, Ref Length: 6
# Pred Length: 6, Ref Length: 9
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 4
# Pred Length: 6, Ref Length: 5
# Pred Length: 4, Ref Length: 7
# Pred Length: 5, Ref Length: 8
# Pred Length: 8, Ref Length: 6
# Pred Length: 4, Ref Length: 5
# Pred Length: 4, Ref Length: 5
# Pred Length: 6, Ref Length: 9
# Pred Length: 5, Ref Length: 6
# Pred Length: 7, Ref Length: 5
# Pred Length: 10, Ref Length: 9
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 7, Ref Length: 5
# Pred Length: 4, Ref Length: 6
# Pred Length: 8, Ref Length: 4
# Pred Length: 5, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 4, Ref Length: 5
# Pred Length: 4, Ref Length: 5
# Pred Length: 9, Ref Length: 8
# Pred Length: 5, Ref Length: 7
# Pred Length: 7, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 6
# Pred Length: 4, Ref Length: 4
# Pred Length: 7, Ref Length: 7
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 3
# Pred Length: 6, Ref Length: 7
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 4
# Pred Length: 7, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 7, Ref Length: 6
# Pred Length: 5, Ref Length: 7
# Pred Length: 4, Ref Length: 7
# Pred Length: 6, Ref Length: 6
# Pred Length: 9, Ref Length: 7
# Pred Length: 8, Ref Length: 7
# Pred Length: 2, Ref Length: 6
# Pred Length: 5, Ref Length: 6
# Pred Length: 9, Ref Length: 6
# Pred Length: 7, Ref Length: 7
# Pred Length: 5, Ref Length: 6
# Pred Length: 6, Ref Length: 4
# Pred Length: 5, Ref Length: 4
# Pred Length: 7, Ref Length: 7
# Pred Length: 6, Ref Length: 5
# Pred Length: 7, Ref Length: 8
# Pred Length: 9, Ref Length: 6
# Pred Length: 9, Ref Length: 8
# Pred Length: 7, Ref Length: 5
# Pred Length: 5, Ref Length: 3
# Pred Length: 5, Ref Length: 4
# Pred Length: 5, Ref Length: 6
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 4
# Pred Length: 6, Ref Length: 8
# Pred Length: 7, Ref Length: 8
# Pred Length: 4, Ref Length: 3
# Pred Length: 5, Ref Length: 5
# Pred Length: 7, Ref Length: 4
# Pred Length: 4, Ref Length: 4
# Pred Length: 9, Ref Length: 7
# Pred Length: 4, Ref Length: 4
# Pred Length: 7, Ref Length: 8
# Pred Length: 5, Ref Length: 5
# Pred Length: 8, Ref Length: 6
# Pred Length: 8, Ref Length: 7
# Pred Length: 5, Ref Length: 7
# Pred Length: 7, Ref Length: 6
# Pred Length: 9, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 4
# Pred Length: 5, Ref Length: 6
# Pred Length: 4, Ref Length: 6
# Pred Length: 5, Ref Length: 6
# Pred Length: 5, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 7
# Pred Length: 7, Ref Length: 8
# Pred Length: 6, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 4
# Pred Length: 5, Ref Length: 6
# Pred Length: 7, Ref Length: 6
# Pred Length: 5, Ref Length: 8
# Pred Length: 5, Ref Length: 3
# Pred Length: 3, Ref Length: 3
# Pred Length: 5, Ref Length: 4
# Pred Length: 7, Ref Length: 7
# Pred Length: 6, Ref Length: 4
# Pred Length: 5, Ref Length: 6
# Pred Length: 4, Ref Length: 8
# Pred Length: 6, Ref Length: 7
# Pred Length: 5, Ref Length: 8
# Pred Length: 5, Ref Length: 4
# Pred Length: 6, Ref Length: 6
# Pred Length: 9, Ref Length: 9
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 7
# Pred Length: 4, Ref Length: 6
# Pred Length: 6, Ref Length: 3
# Pred Length: 6, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 7, Ref Length: 7
# Pred Length: 7, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 3, Ref Length: 5
# Pred Length: 6, Ref Length: 7
# Pred Length: 6, Ref Length: 4
# Pred Length: 6, Ref Length: 4
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 8
# Pred Length: 5, Ref Length: 5
# Pred Length: 10, Ref Length: 8
# Pred Length: 5, Ref Length: 7
# Pred Length: 5, Ref Length: 5
# Pred Length: 8, Ref Length: 8
# Pred Length: 6, Ref Length: 7
# Pred Length: 4, Ref Length: 5
# Pred Length: 5, Ref Length: 4
# Pred Length: 4, Ref Length: 3
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 4
# Pred Length: 5, Ref Length: 7
# Pred Length: 6, Ref Length: 6
# Pred Length: 7, Ref Length: 7
# Pred Length: 7, Ref Length: 3
# Pred Length: 9, Ref Length: 5
# Pred Length: 4, Ref Length: 3
# Pred Length: 5, Ref Length: 6
# Pred Length: 4, Ref Length: 5
# Pred Length: 3, Ref Length: 4
# Pred Length: 10, Ref Length: 7
# Pred Length: 5, Ref Length: 3
# Pred Length: 5, Ref Length: 4
# Pred Length: 8, Ref Length: 4
# Pred Length: 4, Ref Length: 7
# Pred Length: 8, Ref Length: 9
# Pred Length: 6, Ref Length: 5
# Pred Length: 4, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 4
# Pred Length: 5, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 6
# Pred Length: 7, Ref Length: 4
# Pred Length: 7, Ref Length: 8
# Pred Length: 6, Ref Length: 6
# Pred Length: 7, Ref Length: 4
# Pred Length: 6, Ref Length: 6
# Pred Length: 7, Ref Length: 7
# Pred Length: 6, Ref Length: 7
# Pred Length: 7, Ref Length: 6
# Pred Length: 6, Ref Length: 4
# Pred Length: 7, Ref Length: 6
# Pred Length: 6, Ref Length: 6
# Pred Length: 6, Ref Length: 4
# Pred Length: 5, Ref Length: 6
# Pred Length: 6, Ref Length: 7
# Pred Length: 7, Ref Length: 7
# Pred Length: 4, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 7, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 6
# Pred Length: 6, Ref Length: 7
# Pred Length: 4, Ref Length: 7
# Pred Length: 4, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 3, Ref Length: 3
# Pred Length: 4, Ref Length: 6
# Pred Length: 4, Ref Length: 3
# Pred Length: 8, Ref Length: 4
# Pred Length: 6, Ref Length: 6
# Pred Length: 3, Ref Length: 4
# Pred Length: 4, Ref Length: 7
# Pred Length: 4, Ref Length: 6
# Pred Length: 7, Ref Length: 7
# Pred Length: 8, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 4, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 7
# Pred Length: 9, Ref Length: 6
# Pred Length: 6, Ref Length: 7
# Pred Length: 3, Ref Length: 4
# Pred Length: 6, Ref Length: 7
# Pred Length: 5, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 3, Ref Length: 7
# Pred Length: 6, Ref Length: 9
# Pred Length: 6, Ref Length: 5
# Pred Length: 7, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 7, Ref Length: 7
# Pred Length: 6, Ref Length: 6
# Pred Length: 4, Ref Length: 6
# Pred Length: 7, Ref Length: 3
# Pred Length: 9, Ref Length: 6
# Pred Length: 6, Ref Length: 7
# Pred Length: 5, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 9
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 8, Ref Length: 8
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 6, Ref Length: 3
# Pred Length: 4, Ref Length: 3
# Pred Length: 6, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 8, Ref Length: 8
# Pred Length: 3, Ref Length: 3
# Pred Length: 10, Ref Length: 8
# Pred Length: 5, Ref Length: 4
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 8
# Pred Length: 5, Ref Length: 8
# Pred Length: 7, Ref Length: 9
# Pred Length: 4, Ref Length: 6
# Pred Length: 9, Ref Length: 4
# Pred Length: 7, Ref Length: 7
# Pred Length: 5, Ref Length: 3
# Pred Length: 6, Ref Length: 4
# Pred Length: 9, Ref Length: 8
# Pred Length: 9, Ref Length: 6
# Pred Length: 7, Ref Length: 7
# Pred Length: 8, Ref Length: 5
# Pred Length: 5, Ref Length: 6
# Pred Length: 6, Ref Length: 8
# Pred Length: 3, Ref Length: 4
# Pred Length: 7, Ref Length: 7
# Pred Length: 5, Ref Length: 8
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 4, Ref Length: 7
# Pred Length: 4, Ref Length: 4
# Pred Length: 4, Ref Length: 4
# Pred Length: 7, Ref Length: 5
# Pred Length: 6, Ref Length: 8
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 5
# Pred Length: 5, Ref Length: 4
# Pred Length: 8, Ref Length: 5
# Pred Length: 6, Ref Length: 4
# Pred Length: 6, Ref Length: 10
# Pred Length: 6, Ref Length: 6
# Pred Length: 8, Ref Length: 6
# Pred Length: 7, Ref Length: 8
# Pred Length: 4, Ref Length: 5
# Pred Length: 8, Ref Length: 7
# Pred Length: 9, Ref Length: 8
# Pred Length: 9, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 10, Ref Length: 7
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 6
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 4
# Pred Length: 8, Ref Length: 4
# Pred Length: 6, Ref Length: 6
# Pred Length: 3, Ref Length: 3
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 6
# Pred Length: 3, Ref Length: 5
# Pred Length: 7, Ref Length: 7
# Pred Length: 4, Ref Length: 5
# Pred Length: 8, Ref Length: 6
# Pred Length: 3, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 6
# Pred Length: 5, Ref Length: 6
# Pred Length: 7, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 4, Ref Length: 3
# Pred Length: 8, Ref Length: 6
# Pred Length: 4, Ref Length: 5
# Pred Length: 5, Ref Length: 7
# Pred Length: 8, Ref Length: 5
# Pred Length: 4, Ref Length: 7
# Pred Length: 3, Ref Length: 4
# Pred Length: 7, Ref Length: 7
# Pred Length: 4, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 6
# Pred Length: 7, Ref Length: 6
# Pred Length: 5, Ref Length: 6
# Pred Length: 7, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 6, Ref Length: 9
# Pred Length: 5, Ref Length: 6
# Pred Length: 3, Ref Length: 6
# Pred Length: 8, Ref Length: 6
# Pred Length: 4, Ref Length: 7
# Pred Length: 7, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 7
# Pred Length: 8, Ref Length: 10
# Pred Length: 5, Ref Length: 5
# Pred Length: 7, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 8
# Pred Length: 5, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 6, Ref Length: 8
# Pred Length: 3, Ref Length: 7
# Pred Length: 7, Ref Length: 9
# Pred Length: 7, Ref Length: 5
# Pred Length: 5, Ref Length: 7
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 3, Ref Length: 5
# Pred Length: 5, Ref Length: 6
# Pred Length: 3, Ref Length: 3
# Pred Length: 8, Ref Length: 8
# Pred Length: 8, Ref Length: 9
# Pred Length: 2, Ref Length: 3
# Pred Length: 4, Ref Length: 5
# Pred Length: 3, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 3, Ref Length: 8
# Pred Length: 4, Ref Length: 6
# Pred Length: 6, Ref Length: 4
# Pred Length: 10, Ref Length: 8
# Pred Length: 3, Ref Length: 3
# Pred Length: 8, Ref Length: 6
# Pred Length: 15, Ref Length: 6
# Pred Length: 7, Ref Length: 8
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 9
# Pred Length: 6, Ref Length: 6
# Pred Length: 6, Ref Length: 8
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 4
# Pred Length: 6, Ref Length: 10
# Pred Length: 9, Ref Length: 5
# Pred Length: 5, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 6, Ref Length: 7
# Pred Length: 8, Ref Length: 6
# Pred Length: 4, Ref Length: 4
# Pred Length: 5, Ref Length: 4
# Pred Length: 7, Ref Length: 7
# Pred Length: 7, Ref Length: 7
# Pred Length: 5, Ref Length: 3
# Pred Length: 4, Ref Length: 4
# Pred Length: 8, Ref Length: 8
# Pred Length: 5, Ref Length: 4
# Pred Length: 7, Ref Length: 5
# Pred Length: 4, Ref Length: 5
# Pred Length: 8, Ref Length: 6
# Pred Length: 3, Ref Length: 7
# Pred Length: 5, Ref Length: 4
# Pred Length: 4, Ref Length: 7
# Pred Length: 5, Ref Length: 7
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 4
# Pred Length: 5, Ref Length: 5
# Pred Length: 3, Ref Length: 3
# Pred Length: 5, Ref Length: 8
# Pred Length: 4, Ref Length: 5
# Pred Length: 4, Ref Length: 10
# Pred Length: 6, Ref Length: 8
# Pred Length: 6, Ref Length: 4
# Pred Length: 4, Ref Length: 5
# Pred Length: 4, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 5, Ref Length: 5
# Pred Length: 4, Ref Length: 5
# Pred Length: 6, Ref Length: 5
# Pred Length: 4, Ref Length: 7
# Pred Length: 4, Ref Length: 7
# Pred Length: 5, Ref Length: 4
# Pred Length: 7, Ref Length: 5
# Pred Length: 7, Ref Length: 7
# Pred Length: 6, Ref Length: 6
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# Pred Length: 5, Ref Length: 9
# Pred Length: 7, Ref Length: 6
# Pred Length: 5, Ref Length: 7
# Pred Length: 5, Ref Length: 5
# Pred Length: 6, Ref Length: 6
# Pred Length: 10, Ref Length: 7
# Pred Length: 6, Ref Length: 6
# Pred Length: 2, Ref Length: 5
# Pred Length: 6, Ref Length: 4
# Pred Length: 4, Ref Length: 6
# Pred Length: 3, Ref Length: 3
# Pred Length: 3, Ref Length: 3
# Pred Length: 6, Ref Length: 5
# Pred Length: 5, Ref Length: 5
# BLEU Score: 0.23723106801779037
# ROUGE Scores: {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0}

# %%
from rouge_score import rouge_scorer
from unidecode import unidecode

# Initialize the Rouge scorer
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=False)
# Define a function to preprocess and tokenize Bengali text
def preprocess_text(text):
    text = unidecode(text)
    tokens = text.split()
    return ' '.join(tokens)

# Create lists to store individual scores
rouge1_f1_scores = []
rouge1_precision_scores = []
rouge1_recall_scores = []
rouge2_f1_scores = []
rouge2_precision_scores = []
rouge2_recall_scores = []
rougeL_f1_scores = []
rougeL_precision_scores = []
rougeL_recall_scores = []

for ref, pred in zip(references, generated_summaries):
    candidate = preprocess_text(pred)
    reference = preprocess_text(' '.join(ref))
    scores = scorer.score(reference, candidate)

    rouge1_f1_scores.append(scores['rouge1'].fmeasure)
    rouge1_precision_scores.append(scores['rouge1'].precision)
    rouge1_recall_scores.append(scores['rouge1'].recall)
    rouge2_f1_scores.append(scores['rouge2'].fmeasure)
    rouge2_precision_scores.append(scores['rouge2'].precision)
    rouge2_recall_scores.append(scores['rouge2'].recall)
    rougeL_f1_scores.append(scores['rougeL'].fmeasure)
    rougeL_precision_scores.append(scores['rougeL'].precision)
    rougeL_recall_scores.append(scores['rougeL'].recall)

# Calculate the average scores
avg_rouge1_f1 = sum(rouge1_f1_scores) / len(rouge1_f1_scores)
avg_rouge1_precision = sum(rouge1_precision_scores) / len(rouge1_precision_scores)
avg_rouge1_recall = sum(rouge1_recall_scores) / len(rouge1_recall_scores)
avg_rouge2_f1 = sum(rouge2_f1_scores) / len(rouge2_f1_scores)
avg_rouge2_precision = sum(rouge2_precision_scores) / len(rouge2_precision_scores)
avg_rouge2_recall = sum(rouge2_recall_scores) / len(rouge2_recall_scores)
avg_rougeL_f1 = sum(rougeL_f1_scores) / len(rougeL_f1_scores)
avg_rougeL_precision = sum(rougeL_precision_scores) / len(rougeL_precision_scores)
avg_rougeL_recall = sum(rougeL_recall_scores) / len(rougeL_recall_scores)

# %%
# Print the average scores
print("Average Rouge-1 F1 Score:", avg_rouge1_f1)
print("Average Rouge-1 Precision:", avg_rouge1_precision)
print("Average Rouge-1 Recall:", avg_rouge1_recall)

print("Average Rouge-2 F1 Score:", avg_rouge2_f1)
print("Average Rouge-2 Precision:", avg_rouge2_precision)
print("Average Rouge-2 Recall:", avg_rouge2_recall)

print("Average Rouge-L F1 Score:", avg_rougeL_f1)
print("Average Rouge-L Precision:", avg_rougeL_precision)
print("Average Rouge-L Recall:", avg_rougeL_recall)
# Out:
# Average Rouge-1 F1 Score: 0.015420153143465322
# Average Rouge-1 Precision: 0.04021888087744691
# Average Rouge-1 Recall: 0.009738793231195702
# Average Rouge-2 F1 Score: 9.436989392649858e-05
# Average Rouge-2 Precision: 0.00021386374098511583
# Average Rouge-2 Recall: 6.185120790059862e-05
# Average Rouge-L F1 Score: 0.015337988416300722
# Average Rouge-L Precision: 0.0400334683665779
# Average Rouge-L Recall: 0.009684320923019279

# %%
import torch
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from rouge_score import rouge_scorer

# Define the move_to_device function
def move_to_device(batch, device):
    if isinstance(batch, torch.Tensor):
        return batch.to(device)
    elif isinstance(batch, list):
        return [move_to_device(item, device) for item in batch]
    elif isinstance(batch, dict):
        return {key: move_to_device(value, device) for key, value in batch.items()}
    else:
        return batch  # If it's not a tensor, list, or dict, leave it as is

# Smoothing function for BLEU
smoothing_function = SmoothingFunction().method4

# Initialize lists to store generated summaries and references
generated_summaries = []
references = []

# Generate summaries for the test dataset
for batch in test_dataloader:
    # Move the batch to CUDA
    batch = move_to_device(batch, 'cuda')

    input_text = batch['input_ids']  # Access the input_text using the correct key
    labels = batch['labels']  # Access the labels using the correct key

    # Generate summaries
    with torch.no_grad():  # Disable gradient calculation to save memory
        max_length = int(input_text.shape[1] * 0.3)  # Set max_length dynamically
        summary_ids = model.generate(
            input_text,
            max_length=max_length,
            num_beams=4,
            length_penalty=1.0,
            early_stopping=True
        )

    # Move the summary_ids to CPU to decode
    summary_ids = summary_ids.to('cpu')

    # Decode generated summaries and labels
    generated_summary = tokenizer.batch_decode(summary_ids, skip_special_tokens=True)
    reference_summary = tokenizer.batch_decode(labels, skip_special_tokens=True)

    # Extend lists with generated summaries and references
    generated_summaries.extend(generated_summary)
    references.extend(reference_summary)

# Filter out empty predictions and references
filtered_generated_summaries = []
filtered_references = []

for pred, ref in zip(generated_summaries, references):
    if pred.strip() and ref.strip():  # Check if both are non-empty
        filtered_generated_summaries.append(pred)
        filtered_references.append(ref)

# Debug: Check the lengths of the filtered summaries
print(f"Filtered Generated Summaries Count: {len(filtered_generated_summaries)}")
print(f"Filtered References Count: {len(filtered_references)}")

# Calculate BLEU score only for non-empty summaries
bleu_scores = []
for pred, ref in zip(filtered_generated_summaries, filtered_references):
    pred_tokens = tokenizer.tokenize(pred)  # Using tokenizer's tokenization
    ref_tokens = tokenizer.tokenize(ref)    # Same for reference tokens
    print(f"Pred Length: {len(pred_tokens)}, Ref Length: {len(ref_tokens)}")  # Debug lengths
    if pred_tokens and ref_tokens:  # Ensure both are non-empty after tokenization
        score = sentence_bleu([ref_tokens], pred_tokens, smoothing_function=smoothing_function)
        bleu_scores.append(score)

avg_bleu_score = sum(bleu_scores) / len(bleu_scores) if bleu_scores else 0  # Calculate average if scores exist

# Calculate ROUGE score without stemming
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=False)
rouge_scores = {key: [] for key in ['rouge1', 'rouge2', 'rougeL']}
for pred, ref in zip(filtered_generated_summaries, filtered_references):
    scores = scorer.score(ref, pred)
    for key in rouge_scores:
        rouge_scores[key].append(scores[key].fmeasure)
avg_rouge_scores = {key: sum(val) / len(val) for key, val in rouge_scores.items()}

# Print the results
print(f"BLEU Score: {avg_bleu_score}")
print(f"ROUGE Scores: {avg_rouge_scores}")

# %%
print("Generated Summaries: ", generated_summaries[:5])  # Print the first 5 generated summaries
print("References: ", references[:5])  # Print the first 5 reference summaries

# %%
# !pip install unidecode

# %%
from rouge_score import rouge_scorer
from unidecode import unidecode

# Initialize the Rouge scorer
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=False)
# Define a function to preprocess and tokenize Bengali text
def preprocess_text(text):
    text = unidecode(text)
    tokens = text.split()
    return ' '.join(tokens)

# Create lists to store individual scores
rouge1_f1_scores = []
rouge1_precision_scores = []
rouge1_recall_scores = []
rouge2_f1_scores = []
rouge2_precision_scores = []
rouge2_recall_scores = []
rougeL_f1_scores = []
rougeL_precision_scores = []
rougeL_recall_scores = []

for ref, pred in zip(references, generated_summaries):
    candidate = preprocess_text(pred)
    reference = preprocess_text(' '.join(ref))
    scores = scorer.score(reference, candidate)

    rouge1_f1_scores.append(scores['rouge1'].fmeasure)
    rouge1_precision_scores.append(scores['rouge1'].precision)
    rouge1_recall_scores.append(scores['rouge1'].recall)
    rouge2_f1_scores.append(scores['rouge2'].fmeasure)
    rouge2_precision_scores.append(scores['rouge2'].precision)
    rouge2_recall_scores.append(scores['rouge2'].recall)
    rougeL_f1_scores.append(scores['rougeL'].fmeasure)
    rougeL_precision_scores.append(scores['rougeL'].precision)
    rougeL_recall_scores.append(scores['rougeL'].recall)

# Calculate the average scores
avg_rouge1_f1 = sum(rouge1_f1_scores) / len(rouge1_f1_scores)
avg_rouge1_precision = sum(rouge1_precision_scores) / len(rouge1_precision_scores)
avg_rouge1_recall = sum(rouge1_recall_scores) / len(rouge1_recall_scores)
avg_rouge2_f1 = sum(rouge2_f1_scores) / len(rouge2_f1_scores)
avg_rouge2_precision = sum(rouge2_precision_scores) / len(rouge2_precision_scores)
avg_rouge2_recall = sum(rouge2_recall_scores) / len(rouge2_recall_scores)
avg_rougeL_f1 = sum(rougeL_f1_scores) / len(rougeL_f1_scores)
avg_rougeL_precision = sum(rougeL_precision_scores) / len(rougeL_precision_scores)
avg_rougeL_recall = sum(rougeL_recall_scores) / len(rougeL_recall_scores)

# %%
# Print the average scores
print("Average Rouge-1 F1 Score:", avg_rouge1_f1)
print("Average Rouge-1 Precision:", avg_rouge1_precision)
print("Average Rouge-1 Recall:", avg_rouge1_recall)

print("Average Rouge-2 F1 Score:", avg_rouge2_f1)
print("Average Rouge-2 Precision:", avg_rouge2_precision)
print("Average Rouge-2 Recall:", avg_rouge2_recall)

print("Average Rouge-L F1 Score:", avg_rougeL_f1)
print("Average Rouge-L Precision:", avg_rougeL_precision)
print("Average Rouge-L Recall:", avg_rougeL_recall)
